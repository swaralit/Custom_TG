# %% [markdown]
# # Intialisation Steps
# Connecting to Snowflake

# %% [markdown]
# ## Importing required modules

# %%
import pandas as pd
from drg_connect import Snowflake
import qgrid 
from datetime import timedelta, datetime
import math

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Snowflake connection parameter

# %%
##defining parameters of snowflake
snow = Snowflake(role = 'RWD_ANALYTICS_RW',database='SANDBOX_ANALYTICS',schema = 'SANDBOX')
engine = snow.engine

# %reload_ext sql_magic
# %config SQL.output_result = True  #Enable output to std out
# %config SQL.notify_result = False #disable browser notifications
# %config SQL.conn_name = 'engine'  #Set the sql_magic connection engine

# %% [markdown]
# # Queries from here

# %% [markdown]
# # Pelican EHR data

# %% [markdown]
# ## Pelican table details

# %%
# %%read_sql
#
# select * from RWD_DB.RWD.PELICAN_E_LOINC limit 3
# Out:
# Query started at 04:50:17 PM India Standard TimeInitiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...
# ; Query executed in 0.39 m
#   loinc_num           component property time_aspct    system scale_typ  \
# 0    9256-9  Fluid output.total      Vol         Pt  ^Patient        Qn
# 1   38474-3       Acylcarnitine     SCnc         Pt   Bld.dot        Qn
# 2    2404-2           Hemopexin     MCnc         Pt     Urine        Qn
#
#   method_typ        class last_modified chng_type           ...             \
# 0  Estimated  IO_OUT.ATOM    1996-09-06       ADD           ...
# 1       None         CHEM    2008-10-21       NAM           ...
# 2       None         CHEM    2006-10-26       MAJ           ...
#
#   document_section example_ucum_units example_si_ucum_units status_reason  \
# 0             None               None                  None          None
# 1             None             umol/L                  None          None
# 2             None              mg/dL                  None          None
#
#    status_text change_reason_public common_test_rank common_order_rank  \
# 0         None                 None                0                 0
# 1         None                 None                0                 0
# 2         None                 None                0                 0
#
#   common_si_test_rank hl7_attachment_structure
# 0                   0                     None
# 1                   0                     None
# 2                   0                     None
#
# [3 rows x 43 columns]

# %%
# %%read_sql
#
# select * from RWD_DB.RWD.PELICAN_LABORDER limit 3
# Out:
# Query started at 04:54:02 PM India Standard Time; Query executed in 0.14 m
#            laborder_id                            patient_id  \
# 0  1364935398341433546  393E2EED-4D2C-79C7-D150-08E8154D142F
# 1  4177387127494394539  393E2EED-4D2C-79C7-D150-08E8154D142F
# 2 -8421755992989376358  393E2EED-4D2C-79C7-D150-08E8154D142F
#
#                             provider_id            vendor_id loinc_num  \
# 0                                  None  8844736773880785995    2160-0
# 1  D8E5640E-9F96-E7A1-BA57-6E996DF43374  8844736773880785995   43396-1
# 2  D8E5640E-9F96-E7A1-BA57-6E996DF43374  8844736773880785995   30446-9
#
#    result_status report_date observed_at  obs_quan     obs_qual          unit  \
# 0          Final  2015-11-08  2015-11-14      0.96          NaN         mg/dL
# 1          Final  2018-07-31  2018-08-04    212.00          NaN  mg/dL (calc)
# 2  Not available  2018-07-31  2018-08-04       NaN  281266006.0      cells/uL
#
#   is_abnormal abnormal_flag  created_at last_modified transcript_id
# 0        None          None  2015-11-14    2015-11-14          None
# 1        None          None  2018-08-05    2018-08-05          None
# 2        None          None  2018-08-05    2018-08-05          None

# %% [markdown]
# ## Corresponding loinc codes for triglycerides

# %% [markdown]
# ### Things to remember about loinc codes
#  - Format: nnnnn-n
#  - Component: what was measured
#  - Unit: check from laborder table
#  - date: ask/confirm which date to use - report date or observed_at date
#  - there's no 'component' variable in laborder table so create an excel for loinc codes and upload

# %%
# %%read_sql
#
# create or replace table st_ref_loinc as
#
#     select
#         loinc_num,
#         component
#
#     from RWD_DB.RWD.PELICAN_E_LOINC
#
#     where component ilike '%triglyceride%'
#         or component ilike '%hdl%'
#         or component ilike '%cholesterol%'
#         and not component ilike '%ldl%'
# Out:
# Query started at 08:03:17 PM India Standard Time; Query executed in 0.13 m
#                                      status
# 0  Table ST_REF_LOINC successfully created.

# %%
snow.select("select * from st_ref_loinc")
# Out:
#     loinc_num                                          component
# 0      2086-7                                 Cholesterol.in HDL
# 1     50223-7                               Cholesterol crystals
# 2      2087-5                                 Cholesterol.in IDL
# 3     57937-5                              Cholesterol.in HDL 3a
# 4     32289-1                               7-Dehydrocholesterol
# 5     17081-1                             Triglyceride^post CFst
# 6     34472-1                               Cholesterol crystals
# 7     35200-5                                        Cholesterol
# 8      2565-0                                        Cholesterol
# 9     14438-6                                        Cholesterol
# 10    14447-7                                       Triglyceride
# 11    74433-4                            Cholestanol/Cholesterol
# 12    18263-4                                 Cholesterol.in HDL
# 13    14154-9                                Cholesterol sulfate
# 14     5777-8                               Cholesterol crystals
# 15    28554-4                                       Triglyceride
# 16    53527-8                              Triglyceride.in HDL 2
# 17     2094-1                         Cholesterol.non-esterified
# 18    70260-5        Triglyceride.periton fld/Triglyceride.serum
# 19    59250-1                            Tocopherols/Cholesterol
# 20    16616-5              Cholesterol.in HDL/Cholesterol.in LDL
# 21    70269-6            Triglyceride.plr fld/Triglyceride.serum
# 22    35197-3                                 Cholesterol.in HDL
# 23    59571-0                                       Triglyceride
# 24     3047-8                         Triglyceride+ester.in VLDL
# 25    27340-9                                 Cholesterol.in HDL
# 26     2093-3                                        Cholesterol
# 27    57936-7                              Cholesterol.in HDL 2a
# 28    50799-6                               7-Dehydrocholesterol
# 29     9619-8                                       Triglyceride
# ..        ...                                                ...
# 145   21197-9               Cholesterol esters/Cholesterol.total
# 146   32308-9                                        Cholesterol
# 147   25153-8                               Cholesterol crystals
# 148   74359-1   Cholesterol ester transfer protein actual/normal
# 149   53082-4                                        Cholesterol
# 150   70204-3                                Cholesterol.non HDL
# 151    5932-9                                        Cholesterol
# 152   70268-8              Cholesterol.plr fld/Cholesterol.serum
# 153   48620-9                                        Cholesterol
# 154   73852-6  7-Dehydrocholesterol & 8-Dehydrocholesterol panel
# 155   14449-3                                       Triglyceride
# 156   53528-6                              Triglyceride.in HDL 3
# 157   12531-0                                        Cholesterol
# 158   54373-6                         Cholesterol.non-esterified
# 159   46700-1                               7-Dehydrocholesterol
# 160   44915-7              Cholesterol.in LDL/Cholesterol.in HDL
# 161   56035-9              Apolipoprotein A-I/Cholesterol.in HDL
# 162   54469-2     Cholesterol.in HDL 3a/Cholesterol.in HDL.total
# 163   35361-5             Triglyceride.in lipoprotein (little a)
# 164   14439-4                                        Cholesterol
# 165   48089-7                       Cholesterol/Apolipoprotein B
# 166   16614-0                               Cholesterol crystals
# 167   59038-0                                        Cholesterol
# 168   55839-5                 Cholesterol ester transfer protein
# 169   54371-0                                        Cholesterol
# 170   35389-6                        Cholesterol.in chylomicrons
# 171    3044-5                          Triglyceride+ester.in HDL
# 172   66769-1                                       Triglyceride
# 173   58299-9  Age began taking high blood cholesterol medica...
# 174   50339-1                                        Cholesterol
#
# [175 rows x 2 columns]

# %%
# %%read_sql
#
# create or replace temporary table st_loinc_ref1 as
#
# select
#     'loinc' as cat1,
#      loinc_num as value,
#     RELATEDNAMES2 as description,
#     current_date() as active_date,
#     'swar' as active_reason,
#     null as deactive_date,
#     null as deactive_reason,
#     'RWD_DB.RWD.PELICAN_E_LOINC' as source
# from
#    RWD_DB.RWD.PELICAN_E_LOINC
#     where
#         component ilike '%triglyceride%'
# Out:
# Query started at 02:13:19 PM India Standard Time; Query executed in 0.09 m
#                                       status
# 0  Table ST_LOINC_REF1 successfully created.

# %%
# %%read_sql df
#
# select * from st_loinc_ref1
# Out:
# Query started at 02:15:35 PM India Standard Time; Query executed in 0.07 m
#      cat1    value                                        description  \
# 0   loinc  17081-1  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 1   loinc  14447-7  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 2   loinc  28554-4  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 3   loinc  53527-8  Trigl in HDL2; TG; Trigly; Triglycrides; Trig;...
# 4   loinc  70260-5  Trigl Prt; PT-TRIG; TG; Trigly; Triglycrides; ...
# 5   loinc  70269-6  Trigl Plr fld; PF-TRIG; TG; Trigly; Triglycrid...
# 6   loinc  59571-0  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 7   loinc   3047-8  Trigl+VLDL Ester; TG; Trigly; Triglycrides; Tr...
# 8   loinc   9619-8  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 9   loinc   2096-6  Cholest; Chol; Choles; Lipid; Cholesterol tota...
# 10  loinc   2571-8  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 11  loinc   3046-0  Trigl+LDL Ester; TG; Trigly; Triglycrides; Tri...
# 12  loinc  55607-6  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 13  loinc  22731-4  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 14  loinc  69947-0  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 15  loinc  59572-8  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 16  loinc  34695-7  VLDLc; Very low density lipoprotein cholestero...
# 17  loinc  35360-7  Lpa Trigl; Lpa Triglyceride; LP(a) Triglycerid...
# 18  loinc  12951-0  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 19  loinc   3049-4  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 20  loinc  44718-5  VLDL; Very low density lipoproteins; Trigl; TG...
# 21  loinc   3048-6  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 22  loinc  14445-1  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 23  loinc   1644-4  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 24  loinc  44733-4  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 25  loinc  30570-6  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 26  loinc  47210-0  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 27  loinc  12950-2  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 28  loinc  14446-9  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 29  loinc  30524-3  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 30  loinc  14927-8  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 31  loinc  14450-1  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 32  loinc  13899-0  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 33  loinc  29766-3  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 34  loinc  70218-3  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 35  loinc  39801-6  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 36  loinc   3045-2  Trigl+IDL Ester; Beta VLDL; TG; Trigly; Trigly...
# 37  loinc  35363-1  Trig in Chylo; Trigl; TG; Trigly; Triglycrides...
# 38  loinc  53526-0  Trigl in VLDL; TG; Trigly; Triglycrides; Trig;...
# 39  loinc  35362-3  Trig in Chylo; Trigl; TG; Trigly; Triglycrides...
# 40  loinc  70259-7  Trigl Pcar; PC-TRIG; TG; Trigly; Triglycrides;...
# 41  loinc  59036-4  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 42  loinc  14448-5  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 43  loinc  12228-3  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 44  loinc  51605-4  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 45  loinc   3043-7  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 46  loinc  35217-9  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 47  loinc  14449-3  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 48  loinc  53528-6  Trigl in HDL3; TG; Trigly; Triglycrides; Trig;...
# 49  loinc  35361-5  Lpa Trigl; Lpa Triglyceride; LP(a) Triglycerid...
# 50  loinc   3044-5  Trigl+HDL Ester; TG; Trigly; Triglycrides; Tri...
# 51  loinc  66769-1  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
#
#    active_date active_reason deactive_date deactive_reason  \
# 0   2018-12-10          swar          None            None
# 1   2018-12-10          swar          None            None
# 2   2018-12-10          swar          None            None
# 3   2018-12-10          swar          None            None
# 4   2018-12-10          swar          None            None
# 5   2018-12-10          swar          None            None
# 6   2018-12-10          swar          None            None
# 7   2018-12-10          swar          None            None
# 8   2018-12-10          swar          None            None
# 9   2018-12-10          swar          None            None
# 10  2018-12-10          swar          None            None
# 11  2018-12-10          swar          None            None
# 12  2018-12-10          swar          None            None
# 13  2018-12-10          swar          None            None
# 14  2018-12-10          swar          None            None
# 15  2018-12-10          swar          None            None
# 16  2018-12-10          swar          None            None
# 17  2018-12-10          swar          None            None
# 18  2018-12-10          swar          None            None
# 19  2018-12-10          swar          None            None
# 20  2018-12-10          swar          None            None
# 21  2018-12-10          swar          None            None
# 22  2018-12-10          swar          None            None
# 23  2018-12-10          swar          None            None
# 24  2018-12-10          swar          None            None
# 25  2018-12-10          swar          None            None
# 26  2018-12-10          swar          None            None
# 27  2018-12-10          swar          None            None
# 28  2018-12-10          swar          None            None
# 29  2018-12-10          swar          None            None
# 30  2018-12-10          swar          None            None
# 31  2018-12-10          swar          None            None
# 32  2018-12-10          swar          None            None
# 33  2018-12-10          swar          None            None
# 34  2018-12-10          swar          None            None
# 35  2018-12-10          swar          None            None
# 36  2018-12-10          swar          None            None
# 37  2018-12-10          swar          None            None
# 38  2018-12-10          swar          None            None
# 39  2018-12-10          swar          None            None
# 40  2018-12-10          swar          None            None
# 41  2018-12-10          swar          None            None
# 42  2018-12-10          swar          None            None
# 43  2018-12-10          swar          None            None
# 44  2018-12-10          swar          None            None
# 45  2018-12-10          swar          None            None
# 46  2018-12-10          swar          None            None
# 47  2018-12-10          swar          None            None
# 48  2018-12-10          swar          None            None
# 49  2018-12-10          swar          None            None
# 50  2018-12-10          swar          None            None
# 51  2018-12-10          swar          None            None
#
#                         source
# 0   RWD_DB.RWD.PELICAN_E_LOINC
# 1   RWD_DB.RWD.PELICAN_E_LOINC
# 2   RWD_DB.RWD.PELICAN_E_LOINC
# 3   RWD_DB.RWD.PELICAN_E_LOINC
# 4   RWD_DB.RWD.PELICAN_E_LOINC
# 5   RWD_DB.RWD.PELICAN_E_LOINC
# 6   RWD_DB.RWD.PELICAN_E_LOINC
# 7   RWD_DB.RWD.PELICAN_E_LOINC
# 8   RWD_DB.RWD.PELICAN_E_LOINC
# 9   RWD_DB.RWD.PELICAN_E_LOINC
# 10  RWD_DB.RWD.PELICAN_E_LOINC
# 11  RWD_DB.RWD.PELICAN_E_LOINC
# 12  RWD_DB.RWD.PELICAN_E_LOINC
# 13  RWD_DB.RWD.PELICAN_E_LOINC
# 14  RWD_DB.RWD.PELICAN_E_LOINC
# 15  RWD_DB.RWD.PELICAN_E_LOINC
# 16  RWD_DB.RWD.PELICAN_E_LOINC
# 17  RWD_DB.RWD.PELICAN_E_LOINC
# 18  RWD_DB.RWD.PELICAN_E_LOINC
# 19  RWD_DB.RWD.PELICAN_E_LOINC
# 20  RWD_DB.RWD.PELICAN_E_LOINC
# 21  RWD_DB.RWD.PELICAN_E_LOINC
# 22  RWD_DB.RWD.PELICAN_E_LOINC
# 23  RWD_DB.RWD.PELICAN_E_LOINC
# 24  RWD_DB.RWD.PELICAN_E_LOINC
# 25  RWD_DB.RWD.PELICAN_E_LOINC
# 26  RWD_DB.RWD.PELICAN_E_LOINC
# 27  RWD_DB.RWD.PELICAN_E_LOINC
# 28  RWD_DB.RWD.PELICAN_E_LOINC
# 29  RWD_DB.RWD.PELICAN_E_LOINC
# 30  RWD_DB.RWD.PELICAN_E_LOINC
# 31  RWD_DB.RWD.PELICAN_E_LOINC
# 32  RWD_DB.RWD.PELICAN_E_LOINC
# 33  RWD_DB.RWD.PELICAN_E_LOINC
# 34  RWD_DB.RWD.PELICAN_E_LOINC
# 35  RWD_DB.RWD.PELICAN_E_LOINC
# 36  RWD_DB.RWD.PELICAN_E_LOINC
# 37  RWD_DB.RWD.PELICAN_E_LOINC
# 38  RWD_DB.RWD.PELICAN_E_LOINC
# 39  RWD_DB.RWD.PELICAN_E_LOINC
# 40  RWD_DB.RWD.PELICAN_E_LOINC
# 41  RWD_DB.RWD.PELICAN_E_LOINC
# 42  RWD_DB.RWD.PELICAN_E_LOINC
# 43  RWD_DB.RWD.PELICAN_E_LOINC
# 44  RWD_DB.RWD.PELICAN_E_LOINC
# 45  RWD_DB.RWD.PELICAN_E_LOINC
# 46  RWD_DB.RWD.PELICAN_E_LOINC
# 47  RWD_DB.RWD.PELICAN_E_LOINC
# 48  RWD_DB.RWD.PELICAN_E_LOINC
# 49  RWD_DB.RWD.PELICAN_E_LOINC
# 50  RWD_DB.RWD.PELICAN_E_LOINC
# 51  RWD_DB.RWD.PELICAN_E_LOINC

# %%
# Export to check, and then will inactivate codes that are not relevant and re-upload as final reference table
df.to_excel("out/loinccodes_check.xlsx", index=False)

# %% [markdown]
# ## Upload into snowflake

# %%
loinc_ref = pd.read_excel("in/loinc_ref.xlsx")

# %%
snow.drop_table("st_loinc_ref")
# Out:
# DROP TABLE IF EXISTS sandbox_analytics.sandbox.st_loinc_ref;
# Table sandbox.st_loinc_ref dropped!

# %%
snow.upload_dataframe(loinc_ref, "st_loinc_ref")
# Out:
# Upload successful!

# %%
# %%read_sql
#
# select *
# from st_loinc_ref
# where deactive_date is not null
# Out:
# Query started at 05:48:41 PM India Standard Time; Query executed in 0.07 m
#      cat1    value                                        description  \
# 0   loinc   9619-8  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 1   loinc   2096-6  Cholest; Chol; Choles; Lipid; Cholesterol tota...
# 2   loinc  34695-7  VLDLc; Very low density lipoprotein cholestero...
# 3   loinc  44718-5  VLDL; Very low density lipoproteins; Trigl; TG...
# 4   loinc  44733-4  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 5   loinc  70259-7  Trigl Pcar; PC-TRIG; TG; Trigly; Triglycrides;...
# 6   loinc  59036-4  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 7   loinc  14448-5  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 8   loinc  51605-4  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 9   loinc  14449-3  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
# 10  loinc  35361-5  Lpa Trigl; Lpa Triglyceride; LP(a) Triglycerid...
# 11  loinc  66769-1  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...
#
#    active_date active_reason deactive_date  \
# 0   2018-12-10          swar    2018-10-12
# 1   2018-12-10          swar    2018-10-12
# 2   2018-12-10          swar    2018-10-12
# 3   2018-12-10          swar    2018-10-12
# 4   2018-12-10          swar    2018-10-12
# 5   2018-12-10          swar    2018-10-12
# 6   2018-12-10          swar    2018-10-12
# 7   2018-12-10          swar    2018-10-12
# 8   2018-12-10          swar    2018-10-12
# 9   2018-12-10          swar    2018-10-12
# 10  2018-12-10          swar    2018-10-12
# 11  2018-12-10          swar    2018-10-12
#
#                                       deactive_reason  \
# 0         Triglyceride [Mass/volume] in Pleural fluid
# 1                                 cholesterol levels?
# 2                    Cholesterol.in VLDL/Triglyceride
# 3   Lipoprotein.pre-beta/Triglyceride [Mass Ratio]...
# 4                                    Trigl/HDLc SerPl
# 5   Pericardial fluid to serum tryglyceride ratio ...
# 6   Triglyceride [Mass/volume] in Peritoneal dialy...
# 7                 Triglyceride [Mass/volume] in Semen
# 8       Triglyceride [Moles/volume] in Synovial fluid
# 9        Triglyceride [Mass/volume] in Synovial fluid
# 10  Triglyceride in lipoprotein a [Presence] in Se...
# 11    Triglyceride [Moles/volume] in Peritoneal fluid
#
#                         source
# 0   RWD_DB.RWD.PELICAN_E_LOINC
# 1   RWD_DB.RWD.PELICAN_E_LOINC
# 2   RWD_DB.RWD.PELICAN_E_LOINC
# 3   RWD_DB.RWD.PELICAN_E_LOINC
# 4   RWD_DB.RWD.PELICAN_E_LOINC
# 5   RWD_DB.RWD.PELICAN_E_LOINC
# 6   RWD_DB.RWD.PELICAN_E_LOINC
# 7   RWD_DB.RWD.PELICAN_E_LOINC
# 8   RWD_DB.RWD.PELICAN_E_LOINC
# 9   RWD_DB.RWD.PELICAN_E_LOINC
# 10  RWD_DB.RWD.PELICAN_E_LOINC
# 11  RWD_DB.RWD.PELICAN_E_LOINC

# %% [markdown]
# ## Using laborders table

# %% [markdown]
# ### Things to do:
#     - We want unique patients related to the above listed loinc codes.
#     - We then want to stratify them into buckets (see image in next section)

# %%
# %%html
# <img src="img/analysis_plan.png", width=800, height=800)>
# Out:
# <img src="img/analysis_plan.png", width=800, height=800)>

# %% [markdown]
# ## Observation cohort

# %%
# %%read_sql
#
# create or replace table st_tg_obs_cohort as
#
# select
#     patient_id,
#     loinc_num,
#     result_status,
#     report_date,
#     observed_at,
#     obs_quan,
#     obs_qual,
#     unit,
#     last_modified
#
# from
#     RWD_DB.RWD.PELICAN_LABORDER
# where
#     loinc_num in (select value from st_loinc_ref where cat1 = 'loinc' and deactive_date is null)
# Out:
# Query started at 06:32:39 PM India Standard Time; Query executed in 0.55 m
#                                          status
# 0  Table ST_TG_OBS_COHORT successfully created.

# %%
snow.select("select count(distinct patient_id) from st_tg_obs_cohort where left(patient_id, 5) != 'XXX -'")
# Out:
#    COUNT(DISTINCT PATIENT_ID)
# 0                     6461414

# %%
# %%read_sql
# select * from st_tg_obs_cohort limit 100
# Out:
# Query started at 06:38:45 PM India Standard Time; Query executed in 0.12 m
#                               patient_id loinc_num result_status report_date  \
