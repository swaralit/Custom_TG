# %% [markdown]
# # Intialisation Steps
# Connecting to Snowflake

# %% [markdown]
# ## Importing required modules

# %%
import pandas as pd
from drg_connect import Snowflake
import qgrid 
from datetime import timedelta, datetime
import math

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Snowflake connection parameter

# %%
##defining parameters of snowflake
snow = Snowflake(role = 'RWD_ANALYTICS_RW',database='SANDBOX_ANALYTICS',schema = 'SANDBOX')
engine = snow.engine

# %reload_ext sql_magic
# %config SQL.output_result = True  #Enable output to std out
# %config SQL.notify_result = False #disable browser notifications
# %config SQL.conn_name = 'engine'  #Set the sql_magic connection engine

# %% [markdown]
# # Queries from here

# %% [markdown]
# # Pelican EHR data

# %% [markdown]
# ## Pelican loinc table details

# %%
# %%read_sql
#
# select * from RWD_DB.RWD.PELICAN_E_LOINC limit 3
# Out:
# Query started at 10:43:18 AM India Standard TimeInitiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...
# ; Query executed in 0.20 m
#   loinc_num           component property time_aspct    system scale_typ  \
# 0    9256-9  Fluid output.total      Vol         Pt  ^Patient        Qn
# 1   38474-3       Acylcarnitine     SCnc         Pt   Bld.dot        Qn
# 2    2404-2           Hemopexin     MCnc         Pt     Urine        Qn
#
#   method_typ        class last_modified chng_type           ...             \
# 0  Estimated  IO_OUT.ATOM    1996-09-06       ADD           ...
# 1       None         CHEM    2008-10-21       NAM           ...
# 2       None         CHEM    2006-10-26       MAJ           ...
#
#   document_section example_ucum_units example_si_ucum_units status_reason  \
# 0             None               None                  None          None
# 1             None             umol/L                  None          None
# 2             None              mg/dL                  None          None
#
#    status_text change_reason_public common_test_rank common_order_rank  \
# 0         None                 None                0                 0
# 1         None                 None                0                 0
# 2         None                 None                0                 0
#
#   common_si_test_rank hl7_attachment_structure
# 0                   0                     None
# 1                   0                     None
# 2                   0                     None
#
# [3 rows x 43 columns]

# %% [markdown]
# ## Pelican laborder table

# %%
# %%read_sql
#
# select * from RWD_DB.RWD.PELICAN_LABORDER limit 3
# Out:
# Query started at 04:54:02 PM India Standard Time; Query executed in 0.14 m
#            laborder_id                            patient_id  \
# 0  1364935398341433546  393E2EED-4D2C-79C7-D150-08E8154D142F
# 1  4177387127494394539  393E2EED-4D2C-79C7-D150-08E8154D142F
# 2 -8421755992989376358  393E2EED-4D2C-79C7-D150-08E8154D142F
#
#                             provider_id            vendor_id loinc_num  \
# 0                                  None  8844736773880785995    2160-0
# 1  D8E5640E-9F96-E7A1-BA57-6E996DF43374  8844736773880785995   43396-1
# 2  D8E5640E-9F96-E7A1-BA57-6E996DF43374  8844736773880785995   30446-9
#
#    result_status report_date observed_at  obs_quan     obs_qual          unit  \
# 0          Final  2015-11-08  2015-11-14      0.96          NaN         mg/dL
# 1          Final  2018-07-31  2018-08-04    212.00          NaN  mg/dL (calc)
# 2  Not available  2018-07-31  2018-08-04       NaN  281266006.0      cells/uL
#
#   is_abnormal abnormal_flag  created_at last_modified transcript_id
# 0        None          None  2015-11-14    2015-11-14          None
# 1        None          None  2018-08-05    2018-08-05          None
# 2        None          None  2018-08-05    2018-08-05          None

# %% [markdown]
# ## Corresponding loinc codes for triglycerides

# %% [markdown]
# ### Things to remember about loinc codes
#  - Format: nnnnn-n
#  - Component: what was measured
#  - Unit: check from laborder table
#  - date: ask/confirm which date to use - report date or observed_at date
#  - there's no 'component' variable in laborder table so create an excel for loinc codes and upload

# %%
# %%read_sql
#
# create or replace table st_ref_loinc as
#
#     select
#         loinc_num,
#         component
#
#     from RWD_DB.RWD.PELICAN_E_LOINC
#
#     where component ilike '%triglyceride%'
#         or component ilike '%hdl%'
#         or component ilike '%cholesterol%'
#         and not component ilike '%ldl%'
# Out:
# Query started at 08:03:17 PM India Standard Time; Query executed in 0.13 m
#                                      status
# 0  Table ST_REF_LOINC successfully created.

# %%
snow.select("select * from st_ref_loinc")
# Out:
#     loinc_num                                          component
# 0      2086-7                                 Cholesterol.in HDL
# 1     50223-7                               Cholesterol crystals
# 2      2087-5                                 Cholesterol.in IDL
# 3     57937-5                              Cholesterol.in HDL 3a
# 4     32289-1                               7-Dehydrocholesterol
# 5     17081-1                             Triglyceride^post CFst
# 6     34472-1                               Cholesterol crystals
# 7     35200-5                                        Cholesterol
# 8      2565-0                                        Cholesterol
# 9     14438-6                                        Cholesterol
# 10    14447-7                                       Triglyceride
# 11    74433-4                            Cholestanol/Cholesterol
# 12    18263-4                                 Cholesterol.in HDL
# 13    14154-9                                Cholesterol sulfate
# 14     5777-8                               Cholesterol crystals
# 15    28554-4                                       Triglyceride
# 16    53527-8                              Triglyceride.in HDL 2
# 17     2094-1                         Cholesterol.non-esterified
# 18    70260-5        Triglyceride.periton fld/Triglyceride.serum
# 19    59250-1                            Tocopherols/Cholesterol
# 20    16616-5              Cholesterol.in HDL/Cholesterol.in LDL
# 21    70269-6            Triglyceride.plr fld/Triglyceride.serum
# 22    35197-3                                 Cholesterol.in HDL
# 23    59571-0                                       Triglyceride
# 24     3047-8                         Triglyceride+ester.in VLDL
# 25    27340-9                                 Cholesterol.in HDL
# 26     2093-3                                        Cholesterol
# 27    57936-7                              Cholesterol.in HDL 2a
# 28    50799-6                               7-Dehydrocholesterol
# 29     9619-8                                       Triglyceride
# ..        ...                                                ...
# 145   21197-9               Cholesterol esters/Cholesterol.total
# 146   32308-9                                        Cholesterol
# 147   25153-8                               Cholesterol crystals
# 148   74359-1   Cholesterol ester transfer protein actual/normal
# 149   53082-4                                        Cholesterol
# 150   70204-3                                Cholesterol.non HDL
# 151    5932-9                                        Cholesterol
# 152   70268-8              Cholesterol.plr fld/Cholesterol.serum
# 153   48620-9                                        Cholesterol
# 154   73852-6  7-Dehydrocholesterol & 8-Dehydrocholesterol panel
# 155   14449-3                                       Triglyceride
# 156   53528-6                              Triglyceride.in HDL 3
# 157   12531-0                                        Cholesterol
# 158   54373-6                         Cholesterol.non-esterified
# 159   46700-1                               7-Dehydrocholesterol
# 160   44915-7              Cholesterol.in LDL/Cholesterol.in HDL
# 161   56035-9              Apolipoprotein A-I/Cholesterol.in HDL
# 162   54469-2     Cholesterol.in HDL 3a/Cholesterol.in HDL.total
# 163   35361-5             Triglyceride.in lipoprotein (little a)
# 164   14439-4                                        Cholesterol
# 165   48089-7                       Cholesterol/Apolipoprotein B
# 166   16614-0                               Cholesterol crystals
# 167   59038-0                                        Cholesterol
# 168   55839-5                 Cholesterol ester transfer protein
# 169   54371-0                                        Cholesterol
# 170   35389-6                        Cholesterol.in chylomicrons
# 171    3044-5                          Triglyceride+ester.in HDL
# 172   66769-1                                       Triglyceride
# 173   58299-9  Age began taking high blood cholesterol medica...
# 174   50339-1                                        Cholesterol
#
# [175 rows x 2 columns]

# %% [markdown]
# ## Reference table for triglyceride-related loinc codes

# %%
# %%read_sql
#
# create or replace temporary table st_loinc_ref1 as
#
# select
#     'loinc' as cat1,
#     'tg' as cat2,
#     null as cat3,
#      loinc_num as value,
#     RELATEDNAMES2 as description,
#     current_date() as active_date,
#     'swar' as active_reason,
#     null as deactive_date,
#     null as deactive_reason,
#     'RWD_DB.RWD.PELICAN_E_LOINC' as source
# from
#    RWD_DB.RWD.PELICAN_E_LOINC
#     where
#         component ilike '%triglyceride%'
# Out:
# Query started at 07:50:07 PM India Standard Time; Query executed in 0.12 m
#                                       status
# 0  Table ST_LOINC_REF1 successfully created.

# %%
# %%read_sql df
#
# select * from st_loinc_ref1
# Out:
# Query started at 07:50:17 PM India Standard Time; Query executed in 0.07 m
#      cat1 cat2  cat3    value  \
# 0   loinc   tg  None  17081-1
# 1   loinc   tg  None  14447-7
# 2   loinc   tg  None  28554-4
# 3   loinc   tg  None  53527-8
# 4   loinc   tg  None  70260-5
# 5   loinc   tg  None  70269-6
# 6   loinc   tg  None  59571-0
# 7   loinc   tg  None   3047-8
# 8   loinc   tg  None   9619-8
# 9   loinc   tg  None   2096-6
# 10  loinc   tg  None   2571-8
# 11  loinc   tg  None   3046-0
# 12  loinc   tg  None  55607-6
# 13  loinc   tg  None  22731-4
# 14  loinc   tg  None  69947-0
# 15  loinc   tg  None  59572-8
# 16  loinc   tg  None  34695-7
# 17  loinc   tg  None  35360-7
# 18  loinc   tg  None  12951-0
# 19  loinc   tg  None   3049-4
# 20  loinc   tg  None  44718-5
# 21  loinc   tg  None   3048-6
# 22  loinc   tg  None  14445-1
# 23  loinc   tg  None   1644-4
# 24  loinc   tg  None  44733-4
# 25  loinc   tg  None  30570-6
# 26  loinc   tg  None  47210-0
# 27  loinc   tg  None  12950-2
# 28  loinc   tg  None  14446-9
# 29  loinc   tg  None  30524-3
# 30  loinc   tg  None  14927-8
# 31  loinc   tg  None  14450-1
# 32  loinc   tg  None  13899-0
# 33  loinc   tg  None  29766-3
# 34  loinc   tg  None  70218-3
# 35  loinc   tg  None  39801-6
# 36  loinc   tg  None   3045-2
# 37  loinc   tg  None  35363-1
# 38  loinc   tg  None  53526-0
# 39  loinc   tg  None  35362-3
# 40  loinc   tg  None  70259-7
# 41  loinc   tg  None  59036-4
# 42  loinc   tg  None  14448-5
# 43  loinc   tg  None  12228-3
# 44  loinc   tg  None  51605-4
# 45  loinc   tg  None   3043-7
# 46  loinc   tg  None  35217-9
# 47  loinc   tg  None  14449-3
# 48  loinc   tg  None  53528-6
# 49  loinc   tg  None  35361-5
# 50  loinc   tg  None   3044-5
# 51  loinc   tg  None  66769-1
#
#                                           description active_date  \
# 0   Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 1   Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 2   Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 3   Trigl in HDL2; TG; Trigly; Triglycrides; Trig;...  2018-12-17
# 4   Trigl Prt; PT-TRIG; TG; Trigly; Triglycrides; ...  2018-12-17
# 5   Trigl Plr fld; PF-TRIG; TG; Trigly; Triglycrid...  2018-12-17
# 6   Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 7   Trigl+VLDL Ester; TG; Trigly; Triglycrides; Tr...  2018-12-17
# 8   Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 9   Cholest; Chol; Choles; Lipid; Cholesterol tota...  2018-12-17
# 10  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 11  Trigl+LDL Ester; TG; Trigly; Triglycrides; Tri...  2018-12-17
# 12  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 13  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 14  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 15  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 16  VLDLc; Very low density lipoprotein cholestero...  2018-12-17
# 17  Lpa Trigl; Lpa Triglyceride; LP(a) Triglycerid...  2018-12-17
# 18  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 19  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 20  VLDL; Very low density lipoproteins; Trigl; TG...  2018-12-17
# 21  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 22  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 23  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 24  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 25  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 26  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 27  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 28  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 29  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 30  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 31  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 32  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 33  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 34  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 35  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 36  Trigl+IDL Ester; Beta VLDL; TG; Trigly; Trigly...  2018-12-17
# 37  Trig in Chylo; Trigl; TG; Trigly; Triglycrides...  2018-12-17
# 38  Trigl in VLDL; TG; Trigly; Triglycrides; Trig;...  2018-12-17
# 39  Trig in Chylo; Trigl; TG; Trigly; Triglycrides...  2018-12-17
# 40  Trigl Pcar; PC-TRIG; TG; Trigly; Triglycrides;...  2018-12-17
# 41  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 42  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 43  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 44  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 45  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 46  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 47  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 48  Trigl in HDL3; TG; Trigly; Triglycrides; Trig;...  2018-12-17
# 49  Lpa Trigl; Lpa Triglyceride; LP(a) Triglycerid...  2018-12-17
# 50  Trigl+HDL Ester; TG; Trigly; Triglycrides; Tri...  2018-12-17
# 51  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
#
#    active_reason deactive_date deactive_reason                      source
# 0           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 1           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 2           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 3           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 4           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 5           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 6           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 7           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 8           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 9           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 10          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 11          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 12          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 13          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 14          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 15          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 16          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 17          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 18          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 19          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 20          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 21          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 22          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 23          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 24          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 25          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 26          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 27          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 28          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 29          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 30          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 31          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 32          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 33          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 34          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 35          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 36          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 37          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 38          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 39          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 40          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 41          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 42          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 43          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 44          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 45          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 46          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 47          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 48          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 49          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 50          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 51          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC

# %% [markdown]
# ## Reference table for hdl-related loinc codes

# %%
# %%read_sql
#
# create or replace temporary table st_loinc_ref2 as
#
# select
#     'loinc' as cat1,
#     'tg' as cat2,
#     'hdl' as cat3,
#      loinc_num as value,
#     RELATEDNAMES2 as description,
#     current_date() as active_date,
#     'swar' as active_reason,
#     null as deactive_date,
#     null as deactive_reason,
#     'RWD_DB.RWD.PELICAN_E_LOINC' as source
#
#     from
#        RWD_DB.RWD.PELICAN_E_LOINC
#
#     where
#         component ilike '%hdl%'
# Out:
# Query started at 07:51:08 PM India Standard Time; Query executed in 0.07 m
#                                       status
# 0  Table ST_LOINC_REF2 successfully created.

# %%
# %%read_sql df
#
# select * from st_loinc_ref2
# Out:
# Query started at 07:51:17 PM India Standard Time; Query executed in 0.05 m
#      cat1 cat2 cat3    value  \
# 0   loinc   tg  hdl   2086-7
# 1   loinc   tg  hdl  57937-5
# 2   loinc   tg  hdl  18263-4
# 3   loinc   tg  hdl  53527-8
# 4   loinc   tg  hdl  16616-5
# 5   loinc   tg  hdl  35197-3
# 6   loinc   tg  hdl  27340-9
# 7   loinc   tg  hdl  57936-7
# 8   loinc   tg  hdl  26015-8
# 9   loinc   tg  hdl  13460-1
# 10  loinc   tg  hdl   2085-9
# 11  loinc   tg  hdl  47228-2
# 12  loinc   tg  hdl  53135-0
# 13  loinc   tg  hdl  47220-9
# 14  loinc   tg  hdl   9832-7
# 15  loinc   tg  hdl  55607-6
# 16  loinc   tg  hdl  56132-4
# 17  loinc   tg  hdl   9322-9
# 18  loinc   tg  hdl   9833-5
# 19  loinc   tg  hdl  47221-7
# 20  loinc   tg  hdl  26017-4
# 21  loinc   tg  hdl  26016-6
# 22  loinc   tg  hdl  48090-5
# 23  loinc   tg  hdl  54470-0
# 24  loinc   tg  hdl  44733-4
# 25  loinc   tg  hdl  54468-4
# 26  loinc   tg  hdl  50840-8
# 27  loinc   tg  hdl   2095-8
# 28  loinc   tg  hdl  50409-2
# 29  loinc   tg  hdl  56133-2
# 30  loinc   tg  hdl  70200-1
# 31  loinc   tg  hdl  54471-8
# 32  loinc   tg  hdl  43396-1
# 33  loinc   tg  hdl  32309-7
# 34  loinc   tg  hdl  54467-6
# 35  loinc   tg  hdl  12772-0
# 36  loinc   tg  hdl  49130-8
# 37  loinc   tg  hdl  11054-4
# 38  loinc   tg  hdl  35243-5
# 39  loinc   tg  hdl  12771-2
# 40  loinc   tg  hdl   9830-1
# 41  loinc   tg  hdl  14646-4
# 42  loinc   tg  hdl  54372-8
# 43  loinc   tg  hdl  70204-3
# 44  loinc   tg  hdl  53528-6
# 45  loinc   tg  hdl  44915-7
# 46  loinc   tg  hdl  56035-9
# 47  loinc   tg  hdl  54469-2
# 48  loinc   tg  hdl   3044-5
#
#                                           description active_date  \
# 0   HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 1   HDLc 3a; TCHHDL; HDL-C; High density lipoprote...  2018-12-17
# 2   HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 3   Trigl in HDL2; TG; Trigly; Triglycrides; Trig;...  2018-12-17
# 4   HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 5   HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 6   HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 7   HDLc 2a; TCHHDL; HDL-C; High density lipoprote...  2018-12-17
# 8   HDL2c; HDLc; TCHHDL; HDL-C; High density lipop...  2018-12-17
# 9   LDLc; LDL-C; Low density lipoprotein cholester...  2018-12-17
# 10  HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 11  NonHDLc; LDL + IDL + VLDL; Cholest; TC; Choles...  2018-12-17
# 12  HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 13  HDL4+5c; HDLc; TCHHDL; HDL-C; High density lip...  2018-12-17
# 14  HDL2c; HDLc; TCHHDL; HDL-C; High density lipop...  2018-12-17
# 15  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 16  HDLc 2a; TCHHDL; HDL-C; High density lipoprote...  2018-12-17
# 17  Cholest; TC; Cholesterols; HDLc; TCHHDL; HDL-C...  2018-12-17
# 18  HDL3c; HDLc; TCHHDL; HDL-C; High density lipop...  2018-12-17
# 19  HDL1+2c; HDLc; TCHHDL; HDL-C; High density lip...  2018-12-17
# 20  HDL3c; HDLc; TCHHDL; HDL-C; High density lipop...  2018-12-17
# 21  HDL2c; HDLc; TCHHDL; HDL-C; High density lipop...  2018-12-17
# 22  HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 23  HDLc 3b; TCHHDL; HDL-C; High density lipoprote...  2018-12-17
# 24  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 25  HDLc 2b; TCHHDL; HDL-C; High density lipoprote...  2018-12-17
# 26  HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 27  HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 28  HDL2+3c; HDL2c; HDLc; TCHHDL; HDL-C; High dens...  2018-12-17
# 29  HDLc 2b; TCHHDL; HDL-C; High density lipoprote...  2018-12-17
# 30  HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 31  HDLc 3c; TCHHDL; HDL-C; High density lipoprote...  2018-12-17
# 32  NonHDLc; LDL + IDL + VLDL; Cholest; Chol; Chol...  2018-12-17
# 33  Cholest; TC; Cholesterols; HDLc; TCHHDL; HDL-C...  2018-12-17
# 34  HDLc 2a; TCHHDL; HDL-C; High density lipoprote...  2018-12-17
# 35  HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 36  HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 37  LDLc; LDL-C; Low density lipoprotein cholester...  2018-12-17
# 38  HDL3c; HDLc; TCHHDL; HDL-C; High density lipop...  2018-12-17
# 39  HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 40  Cholest; TC; Cholesterols; HDLc; TCHHDL; HDL-C...  2018-12-17
# 41  HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 42  HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 43  NonHDLc; LDL + IDL + VLDL; Cholest; Chol; Chol...  2018-12-17
# 44  Trigl in HDL3; TG; Trigly; Triglycrides; Trig;...  2018-12-17
# 45  LDLc; LDL-C; Low density lipoprotein cholester...  2018-12-17
# 46  Apo A-I; ApoA1; Apolipoprotein A1; HDLc; TCHHD...  2018-12-17
# 47  HDLc 3a; TCHHDL; HDL-C; High density lipoprote...  2018-12-17
# 48  Trigl+HDL Ester; TG; Trigly; Triglycrides; Tri...  2018-12-17
#
#    active_reason deactive_date deactive_reason                      source
# 0           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 1           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 2           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 3           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 4           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 5           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 6           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 7           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 8           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 9           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 10          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 11          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 12          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 13          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 14          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 15          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 16          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 17          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 18          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 19          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 20          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 21          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 22          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 23          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 24          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 25          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 26          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 27          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 28          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 29          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 30          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 31          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 32          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 33          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 34          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 35          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 36          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 37          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 38          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 39          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 40          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 41          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 42          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 43          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 44          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 45          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 46          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 47          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 48          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC

# %% [markdown]
# ## Merging (union) tg and hdl reference tables

# %%
# %%read_sql df
#
# select * from st_loinc_ref1
# union
# select * from st_loinc_ref2
# Out:
# Query started at 07:51:28 PM India Standard Time; Query executed in 0.06 m
#       cat1 cat2  cat3    value  \
# 0    loinc   tg  None   3047-8
# 1    loinc   tg  None  34695-7
# 2    loinc   tg  None  35360-7
# 3    loinc   tg  None   3049-4
# 4    loinc   tg  None   3048-6
# 5    loinc   tg  None   1644-4
# 6    loinc   tg  None  47210-0
# 7    loinc   tg  None  12950-2
# 8    loinc   tg  None  14927-8
# 9    loinc   tg  None  13899-0
# 10   loinc   tg  None  29766-3
# 11   loinc   tg  None  35362-3
# 12   loinc   tg  None  59036-4
# 13   loinc   tg  None  59572-8
# 14   loinc   tg  None  53526-0
# 15   loinc   tg  None   3044-5
# 16   loinc   tg  None  51605-4
# 17   loinc   tg  None  35361-5
# 18   loinc   tg  None   3045-2
# 19   loinc   tg  None  70259-7
# 20   loinc   tg  None   3043-7
# 21   loinc   tg   hdl   2086-7
# 22   loinc   tg   hdl  57937-5
# 23   loinc   tg   hdl  27340-9
# 24   loinc   tg   hdl  47220-9
# 25   loinc   tg   hdl  55607-6
# 26   loinc   tg   hdl   9322-9
# 27   loinc   tg   hdl   9833-5
# 28   loinc   tg   hdl  26017-4
# 29   loinc   tg   hdl  70200-1
# ..     ...  ...   ...      ...
# 71   loinc   tg  None  12951-0
# 72   loinc   tg   hdl  18263-4
# 73   loinc   tg   hdl  53527-8
# 74   loinc   tg   hdl  16616-5
# 75   loinc   tg   hdl  35197-3
# 76   loinc   tg   hdl  57936-7
# 77   loinc   tg   hdl  26015-8
# 78   loinc   tg   hdl  13460-1
# 79   loinc   tg   hdl  53135-0
# 80   loinc   tg   hdl   9832-7
# 81   loinc   tg   hdl  56132-4
# 82   loinc   tg   hdl  47221-7
# 83   loinc   tg   hdl  54470-0
# 84   loinc   tg   hdl  44733-4
# 85   loinc   tg   hdl  56133-2
# 86   loinc   tg   hdl  32309-7
# 87   loinc   tg   hdl  54467-6
# 88   loinc   tg   hdl  47228-2
# 89   loinc   tg   hdl  26016-6
# 90   loinc   tg   hdl  43396-1
# 91   loinc   tg   hdl  14646-4
# 92   loinc   tg   hdl  54372-8
# 93   loinc   tg   hdl  70204-3
# 94   loinc   tg   hdl  53528-6
# 95   loinc   tg   hdl  50840-8
# 96   loinc   tg   hdl  12772-0
# 97   loinc   tg   hdl  56035-9
# 98   loinc   tg   hdl  48090-5
# 99   loinc   tg   hdl  49130-8
# 100  loinc   tg   hdl  54468-4
#
#                                            description active_date  \
# 0    Trigl+VLDL Ester; TG; Trigly; Triglycrides; Tr...  2018-12-17
# 1    VLDLc; Very low density lipoprotein cholestero...  2018-12-17
# 2    Lpa Trigl; Lpa Triglyceride; LP(a) Triglycerid...  2018-12-17
# 3    Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 4    Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 5    Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 6    Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 7    Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 8    Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 9    Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 10   Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 11   Trig in Chylo; Trigl; TG; Trigly; Triglycrides...  2018-12-17
# 12   Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 13   Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 14   Trigl in VLDL; TG; Trigly; Triglycrides; Trig;...  2018-12-17
# 15   Trigl+HDL Ester; TG; Trigly; Triglycrides; Tri...  2018-12-17
# 16   Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 17   Lpa Trigl; Lpa Triglyceride; LP(a) Triglycerid...  2018-12-17
# 18   Trigl+IDL Ester; Beta VLDL; TG; Trigly; Trigly...  2018-12-17
# 19   Trigl Pcar; PC-TRIG; TG; Trigly; Triglycrides;...  2018-12-17
# 20   Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 21   HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 22   HDLc 3a; TCHHDL; HDL-C; High density lipoprote...  2018-12-17
# 23   HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 24   HDL4+5c; HDLc; TCHHDL; HDL-C; High density lip...  2018-12-17
# 25   Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 26   Cholest; TC; Cholesterols; HDLc; TCHHDL; HDL-C...  2018-12-17
# 27   HDL3c; HDLc; TCHHDL; HDL-C; High density lipop...  2018-12-17
# 28   HDL3c; HDLc; TCHHDL; HDL-C; High density lipop...  2018-12-17
# 29   HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# ..                                                 ...         ...
# 71   Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 72   HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 73   Trigl in HDL2; TG; Trigly; Triglycrides; Trig;...  2018-12-17
# 74   HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 75   HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 76   HDLc 2a; TCHHDL; HDL-C; High density lipoprote...  2018-12-17
# 77   HDL2c; HDLc; TCHHDL; HDL-C; High density lipop...  2018-12-17
# 78   LDLc; LDL-C; Low density lipoprotein cholester...  2018-12-17
# 79   HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 80   HDL2c; HDLc; TCHHDL; HDL-C; High density lipop...  2018-12-17
# 81   HDLc 2a; TCHHDL; HDL-C; High density lipoprote...  2018-12-17
# 82   HDL1+2c; HDLc; TCHHDL; HDL-C; High density lip...  2018-12-17
# 83   HDLc 3b; TCHHDL; HDL-C; High density lipoprote...  2018-12-17
# 84   Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 85   HDLc 2b; TCHHDL; HDL-C; High density lipoprote...  2018-12-17
# 86   Cholest; TC; Cholesterols; HDLc; TCHHDL; HDL-C...  2018-12-17
# 87   HDLc 2a; TCHHDL; HDL-C; High density lipoprote...  2018-12-17
# 88   NonHDLc; LDL + IDL + VLDL; Cholest; TC; Choles...  2018-12-17
# 89   HDL2c; HDLc; TCHHDL; HDL-C; High density lipop...  2018-12-17
# 90   NonHDLc; LDL + IDL + VLDL; Cholest; Chol; Chol...  2018-12-17
# 91   HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 92   HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 93   NonHDLc; LDL + IDL + VLDL; Cholest; Chol; Chol...  2018-12-17
# 94   Trigl in HDL3; TG; Trigly; Triglycrides; Trig;...  2018-12-17
# 95   HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 96   HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 97   Apo A-I; ApoA1; Apolipoprotein A1; HDLc; TCHHD...  2018-12-17
# 98   HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 99   HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 100  HDLc 2b; TCHHDL; HDL-C; High density lipoprote...  2018-12-17
#
#     active_reason deactive_date deactive_reason                      source
# 0            swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 1            swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 2            swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 3            swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 4            swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 5            swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 6            swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 7            swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 8            swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 9            swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 10           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 11           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 12           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 13           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 14           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 15           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 16           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 17           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 18           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 19           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 20           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 21           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 22           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 23           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 24           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 25           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 26           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 27           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 28           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 29           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# ..            ...           ...             ...                         ...
# 71           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 72           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 73           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 74           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 75           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 76           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 77           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 78           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 79           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 80           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 81           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 82           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 83           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 84           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 85           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 86           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 87           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 88           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 89           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 90           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 91           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 92           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 93           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 94           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 95           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 96           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 97           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 98           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 99           swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
# 100          swar          None            None  RWD_DB.RWD.PELICAN_E_LOINC
#
# [101 rows x 10 columns]

# %%
# Export to check, and then will inactivate codes that are not relevant and re-upload as final reference table
df.to_excel("out/loinccodes_check.xlsx", index=False)

# %% [markdown]
# ## Upload into snowflake

# %%
loinc_ref = pd.read_excel("in/loinc_ref.xlsx")

# %%
snow.drop_table("st_loinc_ref")
# Out:
# DROP TABLE IF EXISTS sandbox_analytics.sandbox.st_loinc_ref;
# Initiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...
# Table sandbox.st_loinc_ref dropped!

# %%
snow.upload_dataframe(loinc_ref, "st_loinc_ref")
# Out:
# Upload successful!

# %%
# %%read_sql
#
# select *
# from st_loinc_ref
# where deactive_date is not null
# Out:
# Query started at 10:07:12 AM India Standard Time; Query executed in 0.06 m
#      cat1 cat2  cat3    value  \
# 0   loinc   tg  None   3047-8
# 1   loinc   tg  None  34695-7
# 2   loinc   tg  None  35360-7
# 3   loinc   tg  None  12950-2
# 4   loinc   tg  None  13899-0
# 5   loinc   tg  None  29766-3
# 6   loinc   tg  None  59036-4
# 7   loinc   tg  None  53526-0
# 8   loinc   tg  None   3044-5
# 9   loinc   tg  None  51605-4
# 10  loinc   tg  None  35361-5
# 11  loinc   tg  None   3045-2
# 12  loinc   tg  None  70259-7
# 13  loinc   tg   hdl  55607-6
# 14  loinc   tg   hdl   9322-9
# 15  loinc   tg   hdl  70200-1
# 16  loinc   tg   hdl  54471-8
# 17  loinc   tg   hdl   9830-1
# 18  loinc   tg   hdl  44915-7
# 19  loinc   tg   hdl   3044-5
# 20  loinc   tg   hdl   2095-8
# 21  loinc   tg   hdl  11054-4
# 22  loinc   tg   hdl  54469-2
# 23  loinc   tg  None  14447-7
# 24  loinc   tg  None  53527-8
# 25  loinc   tg  None  70260-5
# 26  loinc   tg  None  70269-6
# 27  loinc   tg  None   9619-8
# 28  loinc   tg  None   2096-6
# 29  loinc   tg  None  69947-0
# 30  loinc   tg  None  44718-5
# 31  loinc   tg  None  14445-1
# 32  loinc   tg  None  44733-4
# 33  loinc   tg  None  14446-9
# 34  loinc   tg  None  35363-1
# 35  loinc   tg  None  12228-3
# 36  loinc   tg  None  53528-6
# 37  loinc   tg  None  14448-5
# 38  loinc   tg  None  66769-1
# 39  loinc   tg  None  55607-6
# 40  loinc   tg  None  14449-3
# 41  loinc   tg   hdl  53527-8
# 42  loinc   tg   hdl  13460-1
# 43  loinc   tg   hdl  53135-0
# 44  loinc   tg   hdl  44733-4
# 45  loinc   tg   hdl  47228-2
# 46  loinc   tg   hdl  43396-1
# 47  loinc   tg   hdl  70204-3
# 48  loinc   tg   hdl  53528-6
# 49  loinc   tg   hdl  56035-9
# 50  loinc   tg   hdl  48090-5
#
#                                           description active_date  \
# 0   Trigl+VLDL Ester; TG; Trigly; Triglycrides; Tr...  2018-12-17
# 1   VLDLc; Very low density lipoprotein cholestero...  2018-12-17
# 2   Lpa Trigl; Lpa Triglyceride; LP(a) Triglycerid...  2018-12-17
# 3   Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 4   Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 5   Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 6   Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 7   Trigl in VLDL; TG; Trigly; Triglycrides; Trig;...  2018-12-17
# 8   Trigl+HDL Ester; TG; Trigly; Triglycrides; Tri...  2018-12-17
# 9   Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 10  Lpa Trigl; Lpa Triglyceride; LP(a) Triglycerid...  2018-12-17
# 11  Trigl+IDL Ester; Beta VLDL; TG; Trigly; Trigly...  2018-12-17
# 12  Trigl Pcar; PC-TRIG; TG; Trigly; Triglycrides;...  2018-12-17
# 13  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 14  Cholest; TC; Cholesterols; HDLc; TCHHDL; HDL-C...  2018-12-17
# 15  HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 16  HDLc 3c; TCHHDL; HDL-C; High density lipoprote...  2018-12-17
# 17  Cholest; TC; Cholesterols; HDLc; TCHHDL; HDL-C...  2018-12-17
# 18  LDLc; LDL-C; Low density lipoprotein cholester...  2018-12-17
# 19  Trigl+HDL Ester; TG; Trigly; Triglycrides; Tri...  2018-12-17
# 20  HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 21  LDLc; LDL-C; Low density lipoprotein cholester...  2018-12-17
# 22  HDLc 3a; TCHHDL; HDL-C; High density lipoprote...  2018-12-17
# 23  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 24  Trigl in HDL2; TG; Trigly; Triglycrides; Trig;...  2018-12-17
# 25  Trigl Prt; PT-TRIG; TG; Trigly; Triglycrides; ...  2018-12-17
# 26  Trigl Plr fld; PF-TRIG; TG; Trigly; Triglycrid...  2018-12-17
# 27  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 28  Cholest; Chol; Choles; Lipid; Cholesterol tota...  2018-12-17
# 29  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 30  VLDL; Very low density lipoproteins; Trigl; TG...  2018-12-17
# 31  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 32  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 33  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 34  Trig in Chylo; Trigl; TG; Trigly; Triglycrides...  2018-12-17
# 35  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 36  Trigl in HDL3; TG; Trigly; Triglycrides; Trig;...  2018-12-17
# 37  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 38  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 39  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 40  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 41  Trigl in HDL2; TG; Trigly; Triglycrides; Trig;...  2018-12-17
# 42  LDLc; LDL-C; Low density lipoprotein cholester...  2018-12-17
# 43  HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
# 44  Trigl; TG; Trigly; Triglycrides; Trig; Triglyc...  2018-12-17
# 45  NonHDLc; LDL + IDL + VLDL; Cholest; TC; Choles...  2018-12-17
# 46  NonHDLc; LDL + IDL + VLDL; Cholest; Chol; Chol...  2018-12-17
# 47  NonHDLc; LDL + IDL + VLDL; Cholest; Chol; Chol...  2018-12-17
# 48  Trigl in HDL3; TG; Trigly; Triglycrides; Trig;...  2018-12-17
# 49  Apo A-I; ApoA1; Apolipoprotein A1; HDLc; TCHHD...  2018-12-17
# 50  HDLc; TCHHDL; HDL-C; High density lipoprotein ...  2018-12-17
#
#    active_reason deactive_date  \
# 0           swar    2018-12-18
# 1           swar    2018-12-18
# 2           swar    2018-12-17
# 3           swar    2018-12-18
# 4           swar    2018-12-18
# 5           swar    2018-12-18
# 6           swar    2018-12-17
# 7           swar    2018-12-18
# 8           swar    2018-12-18
# 9           swar    2018-12-18
# 10          swar    2018-12-17
# 11          swar    2018-12-17
# 12          swar    2018-12-17
# 13          swar    2018-12-18
# 14          swar    2018-12-18
# 15          swar    2018-12-18
# 16          swar    2018-12-18
# 17          swar    2018-12-18
# 18          swar    2018-12-18
# 19          swar    2018-12-18
# 20          swar    2018-12-18
# 21          swar    2018-12-18
# 22          swar    2018-12-18
# 23          swar    2018-12-18
# 24          swar    2018-12-18
# 25          swar    2018-12-18
# 26          swar    2018-12-18
# 27          swar    2018-12-17
# 28          swar    2018-12-17
# 29          swar    2018-12-18
# 30          swar    2018-12-17
# 31          swar    2018-12-18
# 32          swar    2018-12-18
# 33          swar    2018-12-18
# 34          swar    2018-12-18
# 35          swar    2018-12-18
# 36          swar    2018-12-18
# 37          swar    2018-12-18
# 38          swar    2018-12-18
# 39          swar    2018-12-18
# 40          swar    2018-12-18
# 41          swar    2018-12-18
# 42          swar    2018-12-18
# 43          swar    2018-12-18
# 44          swar    2018-12-18
# 45          swar    2018-12-18
# 46          swar    2018-12-18
# 47          swar    2018-12-18
# 48          swar    2018-12-18
# 49          swar    2018-12-18
# 50          swar    2018-12-18
#
#                                       deactive_reason  \
# 0                                             tg+vLDL
# 1                                               vLDLc
# 2   Triglyceride in lipoprotein a [Mass/volume] in...
# 3                                         body fluids
# 4      Deprecated Triglyceride [Mass/volume] in fluid
# 5           Triglyceride [Moles/volume] in Body fluid
# 6   Triglyceride [Mass/volume] in Peritoneal dialy...
# 7                                             tg+vLDL
# 8   Triglyceride+ester in HDL [Mass/volume] in Ser...
# 9       Triglyceride [Moles/volume] in Synovial fluid
# 10  Triglyceride in lipoprotein a [Presence] in Se...
# 11  Triglyceride+ester in IDL [Mass/volume] in Ser...
# 12  Triglyceride in pericardial fluid/Triglyceride...
# 13  Triglyceride/Cholesterol in HDL [Molar ratio] ...
# 14  Cholesterol.total/Cholesterol in HDL [Percentile]
# 15  Cholesterol in HDL/Cholesterol.total [Molar ra...
# 16  Cholesterol in HDL 3c/Cholesterol in total HDL...
# 17  Cholesterol.total/Cholesterol in HDL [Mass Rat...
# 18  Cholesterol in LDL/Cholesterol in HDL [Molar r...
# 19  Triglyceride+ester in HDL [Mass/volume] in Ser...
# 20  Cholesterol in HDL/Cholesterol.total [Mass Rat...
# 21  Cholesterol in LDL/Cholesterol in HDL [Mass Ra...
# 22  Cholesterol in HDL 3a/Cholesterol in total HDL...
# 23                                   peritoneal fluid
# 24                                         tg in hdl2
# 25                                   peritoneal fluid
# 26                                thoracentesis fluid
# 27        Triglyceride [Mass/volume] in Pleural fluid
# 28  Cholesterol/Triglyceride [Mass Ratio] in Serum...
# 29                                  pericardial fluid
# 30  Lipoprotein.pre-beta/Triglyceride [Mass Ratio]...
# 31                                     amniotic fluid
# 32  Triglyceride/Cholesterol in HDL [Mass Ratio] i...
# 33                          Tg in cerebrospinal fluid
# 34                                 tg in chylomicrons
# 35                                   Tg in body fluid
# 36  Triglyceride in HDL 3 [Moles/volume] in Serum ...
# 37                Triglyceride [Mass/volume] in Semen
# 38    Triglyceride [Moles/volume] in Peritoneal fluid
# 39  Triglyceride/Cholesterol in HDL [Molar ratio] ...
# 40                              tg in synovial joints
# 41                                         tg in hdl2
# 42                                              LDL-c
# 43                                     dialysis fluid
# 44  Triglyceride/Cholesterol in HDL [Mass Ratio] i...
# 45  Cholesterol non HDL/Cholesterol.total [Mass Ra...
# 46  Cholesterol non HDL [Mass/volume] in Serum or ...
# 47  Cholesterol non HDL [Moles/volume] in Serum or...
# 48  Triglyceride in HDL 3 [Moles/volume] in Serum ...
# 49  Apolipoprotein A-I/Cholesterol in HDL [Mass Ra...
# 50  Cholesterol in HDL/Cholesterol in HDL+VLDL [Mo...
#
#                         source
# 0   RWD_DB.RWD.PELICAN_E_LOINC
# 1   RWD_DB.RWD.PELICAN_E_LOINC
# 2   RWD_DB.RWD.PELICAN_E_LOINC
# 3   RWD_DB.RWD.PELICAN_E_LOINC
# 4   RWD_DB.RWD.PELICAN_E_LOINC
# 5   RWD_DB.RWD.PELICAN_E_LOINC
# 6   RWD_DB.RWD.PELICAN_E_LOINC
# 7   RWD_DB.RWD.PELICAN_E_LOINC
# 8   RWD_DB.RWD.PELICAN_E_LOINC
# 9   RWD_DB.RWD.PELICAN_E_LOINC
# 10  RWD_DB.RWD.PELICAN_E_LOINC
# 11  RWD_DB.RWD.PELICAN_E_LOINC
# 12  RWD_DB.RWD.PELICAN_E_LOINC
# 13  RWD_DB.RWD.PELICAN_E_LOINC
# 14  RWD_DB.RWD.PELICAN_E_LOINC
# 15  RWD_DB.RWD.PELICAN_E_LOINC
# 16  RWD_DB.RWD.PELICAN_E_LOINC
# 17  RWD_DB.RWD.PELICAN_E_LOINC
# 18  RWD_DB.RWD.PELICAN_E_LOINC
# 19  RWD_DB.RWD.PELICAN_E_LOINC
# 20  RWD_DB.RWD.PELICAN_E_LOINC
# 21  RWD_DB.RWD.PELICAN_E_LOINC
# 22  RWD_DB.RWD.PELICAN_E_LOINC
# 23  RWD_DB.RWD.PELICAN_E_LOINC
# 24  RWD_DB.RWD.PELICAN_E_LOINC
# 25  RWD_DB.RWD.PELICAN_E_LOINC
# 26  RWD_DB.RWD.PELICAN_E_LOINC
# 27  RWD_DB.RWD.PELICAN_E_LOINC
# 28  RWD_DB.RWD.PELICAN_E_LOINC
# 29  RWD_DB.RWD.PELICAN_E_LOINC
# 30  RWD_DB.RWD.PELICAN_E_LOINC
# 31  RWD_DB.RWD.PELICAN_E_LOINC
# 32  RWD_DB.RWD.PELICAN_E_LOINC
# 33  RWD_DB.RWD.PELICAN_E_LOINC
# 34  RWD_DB.RWD.PELICAN_E_LOINC
# 35  RWD_DB.RWD.PELICAN_E_LOINC
# 36  RWD_DB.RWD.PELICAN_E_LOINC
# 37  RWD_DB.RWD.PELICAN_E_LOINC
# 38  RWD_DB.RWD.PELICAN_E_LOINC
# 39  RWD_DB.RWD.PELICAN_E_LOINC
# 40  RWD_DB.RWD.PELICAN_E_LOINC
# 41  RWD_DB.RWD.PELICAN_E_LOINC
# 42  RWD_DB.RWD.PELICAN_E_LOINC
# 43  RWD_DB.RWD.PELICAN_E_LOINC
# 44  RWD_DB.RWD.PELICAN_E_LOINC
# 45  RWD_DB.RWD.PELICAN_E_LOINC
# 46  RWD_DB.RWD.PELICAN_E_LOINC
# 47  RWD_DB.RWD.PELICAN_E_LOINC
# 48  RWD_DB.RWD.PELICAN_E_LOINC
# 49  RWD_DB.RWD.PELICAN_E_LOINC
# 50  RWD_DB.RWD.PELICAN_E_LOINC

# %% [markdown]
# # Patient cohorts
# - Using laborders table

# %% [markdown]
# ### Things to do:
# - We want unique patients related to the above listed loinc codes.
# - We then want to stratify them into buckets (see image in next section)
#     - p.s.: these buckets have to be greater than or equal to

# %%
# %%html
# <img src="img/analysis_plan.png", width=800, height=800)>
# Out:
# <img src="img/analysis_plan.png", width=800, height=800)>

# %% [markdown]
# ## Observation cohort
# - Including all patients who have a loinc code pertaining to tg or hdl

# %%
# %%read_sql
#
# create or replace table st_tg_obs_cohort as
#
# select
#     patient_id,
#     loinc_num,
#     result_status,
#     report_date,
#     obs_quan,
#     obs_qual,
#     unit
#
# from
#     RWD_DB.RWD.PELICAN_LABORDER
# where
#     loinc_num in (select value from st_loinc_ref where cat1 = 'loinc' and deactive_date is null)
# Out:
# Query started at 10:08:08 AM India Standard Time; Query executed in 0.65 m
#                                          status
# 0  Table ST_TG_OBS_COHORT successfully created.

# %%
snow.select("select count(distinct patient_id) from st_tg_obs_cohort where left(patient_id, 5) != 'XXX -'")
# Out:
#    COUNT(DISTINCT PATIENT_ID)
# 0                     7513315

# %%
# %%read_sql
# select * from st_tg_obs_cohort limit 100
# Out:
# Query started at 10:23:04 AM India Standard Time; Query executed in 0.10 m
#                               patient_id loinc_num result_status report_date  \
# 0   8BDCAEB0-2AB1-2F28-BBA9-D6C666A97600    2571-8         Final  2013-12-16
# 1   8BDCAEB0-2AB1-2F28-BBA9-D6C666A97600    2085-9         Final  2013-12-16
# 2   AF707EC3-1FA8-B7ED-8A46-D9FD8C388409    2085-9         Final  2018-11-01
# 3   AF707EC3-1FA8-B7ED-8A46-D9FD8C388409    2571-8         Final  2018-11-01
# 4   AF707EC3-1FA8-B7ED-8A46-D9FD8C388409    2085-9         Final  2018-07-01
# 5   AF707EC3-1FA8-B7ED-8A46-D9FD8C388409    2571-8         Final  2018-07-01
# 6   C354043B-E973-EBC0-28CD-1D64CE28F77B    2085-9         Final  2015-05-13
# 7   C99EC882-3033-9146-F916-46BB3058198B    2571-8         Final  2017-03-03
# 8   C99EC882-3033-9146-F916-46BB3058198B    2085-9         Final  2017-03-03
# 9   C99EC882-3033-9146-F916-46BB3058198B    2085-9         Final  2015-02-15
# 10  C99EC882-3033-9146-F916-46BB3058198B    2571-8         Final  2015-02-15
# 11  C99EC882-3033-9146-F916-46BB3058198B    2085-9         Final  2018-03-05
# 12  C99EC882-3033-9146-F916-46BB3058198B    2571-8         Final  2014-02-10
# 13  C99EC882-3033-9146-F916-46BB3058198B    2571-8         Final  2018-03-05
# 14  8802EF0A-262A-B400-409A-D2C228A583C4    2085-9         Final  2015-11-05
# 15  8802EF0A-262A-B400-409A-D2C228A583C4    2085-9         Final  2013-12-27
# 16  D3AF3932-FB5F-1FC2-E4E5-7AD7B21BB2DC    2085-9         Final  2012-04-04
# 17  D3AF3932-FB5F-1FC2-E4E5-7AD7B21BB2DC    2085-9         Final  2013-03-07
# 18  524DC39C-0137-52EA-9A0E-94A0DE1459BF    2085-9         Final  2016-08-20
# 19  524DC39C-0137-52EA-9A0E-94A0DE1459BF    2571-8         Final  2016-08-20
# 20  75CFD5EA-6DDC-0A2F-4107-BAD0211E95C8    2571-8         Final  2012-01-28
# 21  75CFD5EA-6DDC-0A2F-4107-BAD0211E95C8    2571-8         Final  2012-11-04
# 22  75CFD5EA-6DDC-0A2F-4107-BAD0211E95C8    2571-8         Final  2013-03-27
# 23  75CFD5EA-6DDC-0A2F-4107-BAD0211E95C8    2085-9         Final  2013-03-27
# 24  75CFD5EA-6DDC-0A2F-4107-BAD0211E95C8    2085-9         Final  2012-01-28
# 25  75CFD5EA-6DDC-0A2F-4107-BAD0211E95C8    2571-8         Final  2012-07-18
# 26  75CFD5EA-6DDC-0A2F-4107-BAD0211E95C8    2085-9         Final  2012-07-18
# 27  75CFD5EA-6DDC-0A2F-4107-BAD0211E95C8    2085-9         Final  2012-11-04
# 28  75CFD5EA-6DDC-0A2F-4107-BAD0211E95C8    2085-9         Final  2014-07-31
# 29  F0AA0431-190F-5714-CA53-AD978C0367FF    2085-9         Final  2014-07-14
# ..                                   ...       ...           ...         ...
# 70  DEFAED88-0726-89F1-4748-641C9E5D47F9    2571-8         Final  2016-08-14
# 71  DEFAED88-0726-89F1-4748-641C9E5D47F9    2085-9         Final  2016-08-14
# 72  7082A544-7BA2-5E53-77BE-CF7A79C44560    2571-8         Final  2016-03-14
# 73  7082A544-7BA2-5E53-77BE-CF7A79C44560    2085-9         Final  2016-03-14
# 74  45E69548-0C1C-CA2E-5FC1-DFA50328E2A3    2571-8         Final  2017-10-08
# 75  45E69548-0C1C-CA2E-5FC1-DFA50328E2A3    2085-9         Final  2017-10-08
# 76  E9370DF1-AFA6-B921-0647-9EAA93FB94C6    2571-8         Final  2017-12-01
# 77  E9370DF1-AFA6-B921-0647-9EAA93FB94C6    2085-9         Final  2017-12-01
# 78  98BC57C7-09C8-E779-B8F3-4317C178E413    2571-8         Final  2017-03-09
# 79  98BC57C7-09C8-E779-B8F3-4317C178E413    2085-9         Final  2017-03-09
# 80  F632E6D7-BD49-8FB9-7FDA-D7C9B2009C0A    2571-8         Final  2016-04-16
# 81  F632E6D7-BD49-8FB9-7FDA-D7C9B2009C0A    2085-9         Final  2016-04-16
# 82  F632E6D7-BD49-8FB9-7FDA-D7C9B2009C0A    2085-9         Final  2013-03-02
# 83  F632E6D7-BD49-8FB9-7FDA-D7C9B2009C0A    2085-9         Final  2015-01-27
# 84  F632E6D7-BD49-8FB9-7FDA-D7C9B2009C0A    2571-8         Final  2013-03-02
# 85  FF9DE826-8BA3-A73E-D422-8B03D4D24F08    2571-8         Final  2017-03-04
# 86  FF9DE826-8BA3-A73E-D422-8B03D4D24F08    2085-9         Final  2017-03-04
# 87  C348EEA3-92E1-4D4F-C78A-14621D57BAC0    2085-9         Final  2018-10-10
# 88  C348EEA3-92E1-4D4F-C78A-14621D57BAC0    2571-8         Final  2018-10-10
# 89  FEF474D7-29E5-C879-9A97-14599109B88A    2085-9         Final  2013-01-23
# 90  429FF309-D2DF-695A-D4AE-906670158201    2571-8         Final  2018-06-24
# 91  429FF309-D2DF-695A-D4AE-906670158201    2085-9         Final  2018-06-24
# 92  AAB3F4D3-BA14-425B-EDED-CFC93C06B787    2085-9         Final  2013-10-16
# 93  AAB3F4D3-BA14-425B-EDED-CFC93C06B787    2085-9         Final  2014-09-26
# 94  AAB3F4D3-BA14-425B-EDED-CFC93C06B787    2085-9         Final  2015-03-27
# 95  AAB3F4D3-BA14-425B-EDED-CFC93C06B787    2085-9         Final  2014-04-23
# 96  DC4C2B80-2F91-2338-F0C6-AE6779309F86    2085-9         Final  2013-08-13
# 97  DC4C2B80-2F91-2338-F0C6-AE6779309F86    2085-9         Final  2012-07-18
# 98  DC4C2B80-2F91-2338-F0C6-AE6779309F86    2085-9         Final  2014-02-13
# 99  F4DE20E9-3D19-9B36-BE80-655A78EBCC1F    2085-9         Final  2013-08-08
#
#     obs_quan obs_qual   unit
# 0       66.0     None  mg/dL
# 1       79.0     None  mg/dL
# 2       47.0     None  mg/dL
# 3      150.0     None  mg/dL
# 4       41.0     None  mg/dL
# 5      223.0     None  mg/dL
# 6       46.0     None  mg/dL
# 7      165.0     None  mg/dL
# 8       55.0     None  mg/dL
# 9       66.0     None  mg/dL
# 10     134.0     None  mg/dL
# 11      73.0     None  mg/dL
# 12     134.0     None  mg/dL
# 13     177.0     None  mg/dL
# 14      31.0     None  MG/DL
# 15      33.0     None  mg/dL
# 16      71.0     None  mg/dL
# 17      68.0     None  mg/dL
# 18      58.0     None  MG/DL
# 19      73.0     None  MG/DL
# 20     266.0     None  mg/dL
# 21     119.0     None  mg/dL
# 22     291.0     None  mg/dL
# 23      37.0     None  mg/dL
# 24      31.0     None  mg/dL
# 25     222.0     None  mg/dL
# 26      40.0     None  mg/dL
# 27      44.0     None  mg/dL
# 28      43.0     None  mg/dL
# 29      60.0     None  mg/dL
# ..       ...      ...    ...
# 70     188.0     None  mg/dL
# 71      62.0     None  mg/dL
# 72     214.0     None  mg/dL
# 73      36.0     None  mg/dL
# 74      32.0     None  mg/dL
# 75      43.0     None  mg/dL
# 76      84.0     None  mg/dL
# 77      49.0     None  mg/dL
# 78      50.0     None  mg/dL
# 79      52.0     None  mg/dL
# 80      73.0     None  mg/dL
# 81      75.0     None  mg/dL
# 82      46.0     None  mg/dL
# 83      65.0     None  mg/dL
# 84      84.0     None  mg/dL
# 85      70.0     None  mg/dL
# 86      60.0     None  mg/dL
# 87      30.0     None  mg/dL
# 88     166.0     None  mg/dL
# 89      44.0     None  mg/dL
# 90      85.0     None  mg/dL
# 91      65.0     None  mg/dL
# 92      50.0     None  mg/dL
# 93      60.0     None  mg/dL
# 94      61.0     None  mg/dL
# 95      44.0     None  mg/dL
# 96      82.0     None  mg/dL
# 97      82.0     None  mg/dL
# 98      87.0     None  mg/dL
# 99      36.0     None  mg/dL
#
# [100 rows x 7 columns]

# %% [markdown]
# ## Categorizing by triglyceride levels
#
# - Every patient should have tg level and hdl level values
# - Use latest report_date for distinct patient_id
# - Ask if we want gender as a field?

# %%
snow.select("select distinct cat3 from st_loinc_ref")
# Out:
#   cat2
# 0   tg
# 1  hdl

# %% [markdown]
# ### Triglyceride cohorts
# - Selecting all patients with corresponding triglyceride level
# - **Need 4 different tables for each category of triglycerides**

# %% [markdown]
# #### Tg levels lt 150 and gt=150

# %%
# %%read_sql
#
# create or replace table st_tg_cohort1 as
#
#     select patient_id,
#            report_date,
#            obs_quan,
#            unit,
#
#            case
#                when obs_quan < 150 then 'tg_lt150'
#                when obs_quan >= 150 then 'tg_gt150'
#
#            end as tg_level
#
#     from st_tg_obs_cohort
#
#         where loinc_num in (select value from st_loinc_ref where cat1 = 'loinc' and cat2 = 'tg'
#                             and cat3 is null and deactive_date is null)
#                and result_status ilike '%Final%'
#                --and report_date = (select max(report_date) from st_tg_obs_cohort)
# Out:
# Query started at 04:25:06 PM India Standard Time; Query executed in 0.35 m
#                                       status
# 0  Table ST_TG_COHORT1 successfully created.

# %%
snow.select("select * from st_tg_cohort1 limit 10")
# Out:
#                              patient_id report_date  obs_quan   unit  tg_level
# 0  C6A6FADB-55DE-3B13-1BAB-872046D74F9E  2018-11-04     134.0  mg/dL  tg_lt150
# 1  AFDD01E3-692F-CD3D-4766-891697A4DE81  2018-11-04      86.0  mg/dL  tg_lt150
# 2  CD813F7A-96B7-1909-11FC-15A5A5204064  2018-11-04      52.0  mg/dL  tg_lt150
# 3  8EA86E9A-C379-A096-EAB0-19B7D6CD26D0  2018-11-04     401.0  mg/dl  tg_gt150
# 4  823C97EA-BE80-ED29-09CE-C613E163BB0D  2018-11-04     146.6  mg/dL  tg_lt150
# 5  054105B9-ED84-E962-8293-B606AE6BA3C1  2018-11-04     144.0  mg/dL  tg_lt150
# 6  6CC71E57-06FB-4A8C-C1B3-F5E7380C5789  2018-11-04     113.0  mg/dl  tg_lt150
# 7  E855C4D3-4DFB-4BB3-DF14-4838C70FB87A  2018-11-04      61.0  MG/DL  tg_lt150
# 8  C5C69953-8236-4AAB-000C-8C7E85F0FB31  2018-11-04     110.0  mg/dL  tg_lt150
# 9  E03837F3-2C4F-17E5-BA08-DA5D0E71231F  2018-11-04      51.0  MG/DL  tg_lt150

# %%
# %%read_sql
#
# select  tg_level,
#         count(distinct patient_id)
#
#         from st_tg_cohort1
#
#         --where unit ilike '%mg/dL%'
#            --and hdl_unit ilike '%mg/dL%'
#
#         group by tg_level
#         --order by tg_level
# Out:
# Query started at 04:33:06 PM India Standard Time; Query executed in 0.08 m
#    tg_level  COUNT(DISTINCT PATIENT_ID)
# 0      None                       46315
# 1  tg_lt150                     5005397
# 2  tg_gt150                     2372089

# %% [markdown]
# #### Tg levels >=180

# %%
# %%read_sql
#
# create or replace table st_tg_cohort2 as
#
#     select patient_id,
#            report_date,
#            obs_quan,
#            unit,
#
#            case
#                when obs_quan >= 180 then 'tg_gt180'
#
#            end as tg_level
#
#     from st_tg_obs_cohort
#
#         where loinc_num in (select value from st_loinc_ref where cat1 = 'loinc' and cat2 = 'tg'
#                             and cat3 is null and deactive_date is null)
#                and result_status ilike '%Final%'
#                --and report_date = (select max(report_date) from st_tg_obs_cohort)
# Out:
# Query started at 04:34:17 PM India Standard Time; Query executed in 0.24 m
#                                       status
# 0  Table ST_TG_COHORT2 successfully created.

# %%
snow.select("select * from st_tg_cohort2 limit 10")
# Out:
#                              patient_id report_date  obs_quan   unit  tg_level
# 0  9A3AE741-223A-164A-BD57-1C3EA4DC2D59  2018-11-04      53.0  mg/dL      None
# 1  4A1F84EC-42C8-7253-0053-67140CB6C6F2  2018-11-04      78.0  mg/dL      None
# 2  23CF83B7-75D1-CAC5-77B4-6B9CFE9E74BA  2018-11-04      66.0  mg/dL      None
# 3  3B1E92D2-0E7B-A6A3-580E-F86419239DF0  2018-11-04      69.0  mg/dL      None
# 4  EF017586-A0D3-7D44-BE1F-7E9D530793E3  2018-11-04     214.0  mg/dL  tg_gt180
# 5  7B2CB51E-7763-1CD6-98D8-E99F91DEF2A5  2018-11-04      71.0  mg/dL      None
# 6  FA307D76-13C8-BDC4-A4D9-DF87CBADA914  2018-11-04     190.0  mg/dL  tg_gt180
# 7  5E874B1B-C785-89D1-699C-48BA221FBBEC  2018-11-04     289.0  mg/dL  tg_gt180
# 8  E2B013ED-0919-2480-A5E0-0840D4BE5F7C  2018-11-04     140.0  mg/dL      None
# 9  3DEE1949-31DC-42DF-E4C2-8E8D90E6A582  2018-11-04     146.0  mg/dL      None

# %%
# %%read_sql
#
# select  tg_level,
#         count(distinct patient_id)
#
#         from st_tg_cohort2
#
#         --where unit ilike '%mg/dL%'
#            --and hdl_unit ilike '%mg/dL%'
#
#         group by tg_level
#         --order by tg_level
# Out:
# Query started at 04:36:56 PM India Standard Time; Query executed in 0.13 m
#    tg_level  COUNT(DISTINCT PATIENT_ID)
# 0      None                     5556695
# 1  tg_gt180                     1678492

# %% [markdown]
# #### Tg levels >=200

# %%
# %%read_sql
#
# create or replace table st_tg_cohort3 as
#
#     select patient_id,
#            report_date,
#            obs_quan,
#            unit,
#
#            case
#                when obs_quan >= 200 then 'tg_gt200'
#
#            end as tg_level
#
#     from st_tg_obs_cohort
#
#         where loinc_num in (select value from st_loinc_ref where cat1 = 'loinc' and cat2 = 'tg'
#                             and cat3 is null and deactive_date is null)
#                and result_status ilike '%Final%'
#                --and report_date = (select max(report_date) from st_tg_obs_cohort)
# Out:
# Query started at 04:38:06 PM India Standard Time; Query executed in 0.14 m
#                                       status
# 0  Table ST_TG_COHORT3 successfully created.

# %%
snow.select("select * from st_tg_cohort3 limit 20")
# Out:
#                               patient_id report_date  obs_quan   unit  \
# 0   B21E265B-9584-FF3F-B689-D61CAB2BFE7A  2018-11-04      97.0  mg/dL
# 1   DF31E7D4-A12D-C21E-29F8-4664A2852C00  2018-11-04     167.0  mg/dL
# 2   615243F8-208A-2466-0D88-A040C0AE8D5D  2018-11-04     157.0  mg/dL
# 3   F00B8CB4-F30C-76D5-767A-A13ACAD6951D  2018-11-04      66.0  mg/dL
# 4   39C218C3-DB44-981C-A4BE-0478D5FE1A03  2018-11-04      36.0  mg/dL
# 5   C4E869E0-5E14-8635-C335-F554381FA55C  2018-11-04     353.0  mg/dL
# 6   F32741AB-E168-4373-6CE4-1728CBECC87F  2018-11-04      51.0  mg/dL
# 7   742AD839-34C6-46F8-1A42-C12D2F2F820C  2018-11-04      49.0  mg/dL
# 8   A0E8CBBD-D809-53B8-6F4F-D17E4B6DD139  2018-11-04     167.0  mg/dL
# 9   45E060D4-6E80-CC39-6ED7-4AE5A74D9983  2018-11-04     103.0  mg/dL
# 10  9D5D26B6-B5D5-48BE-EC1C-F32A749D3D86  2018-11-04      67.0  mg/dL
# 11  5F250E9C-47F0-483A-F134-7ACE8DC91527  2018-11-04     101.0  mg/dL
# 12  738ADAA8-FE1A-DBB3-CCA4-5D4D5B248870  2018-11-04     123.0  mg/dL
# 13  5716B92E-3E1B-7166-69D8-76D3FEB7807A  2018-11-04     181.0  mg/dL
# 14  86DED6C4-ECFF-D144-F5D6-FA70AEBE66BF  2018-11-04      78.0  mg/dL
# 15  DBEC7885-5649-1B54-6D70-0856F5948915  2018-11-04     169.0  mg/dL
# 16  DF721DC1-460F-D04A-AB55-C654BAF3BEF8  2018-11-04      93.0  mg/dL
# 17  6B36DE89-286B-E24D-06C4-63B6CD0236C8  2018-11-04     224.0  mg/dL
# 18  D230AB37-AFE5-1371-84C4-0D4A048AD2C4  2018-11-04      82.0  mg/dL
# 19  BD6C4961-7207-E9AD-20F7-7D9B62CD1FBD  2018-11-04      80.0  mg/dL
#
#     tg_level
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# 5   tg_gt200
# 6       None
# 7       None
# 8       None
# 9       None
# 10      None
# 11      None
# 12      None
# 13      None
# 14      None
# 15      None
# 16      None
# 17  tg_gt200
# 18      None
# 19      None

# %%
# %%read_sql
#
# select  tg_level,
#         count(distinct patient_id)
#
#         from st_tg_cohort3
#
#         --where unit ilike '%mg/dL%'
#            --and hdl_unit ilike '%mg/dL%'
#
#         group by tg_level
#         --order by tg_level
# Out:
# Query started at 04:38:24 PM India Standard Time; Query executed in 0.10 m
#    tg_level  COUNT(DISTINCT PATIENT_ID)
# 0  tg_gt200                     1337137
# 1      None                     5782422

# %% [markdown]
# #### Tg levels >=500

# %%
# %%read_sql
#
# create or replace table st_tg_cohort4 as
#
#     select patient_id,
#            report_date,
#            obs_quan,
#            unit,
#
#            case
#                when obs_quan >= 500 then 'tg_gt500'
#
#            end as tg_level
#
#     from st_tg_obs_cohort
#
#         where loinc_num in (select value from st_loinc_ref where cat1 = 'loinc' and cat2 = 'tg'
#                             and cat3 is null and deactive_date is null)
#                and result_status ilike '%Final%'
#                --and report_date = (select max(report_date) from st_tg_obs_cohort)
# Out:
# Query started at 04:39:03 PM India Standard Time; Query executed in 0.11 m
#                                       status
# 0  Table ST_TG_COHORT4 successfully created.

# %%
snow.select("select * from st_tg_cohort4 limit 50")
# Out:
#                               patient_id report_date  obs_quan   unit tg_level
# 0   EC686422-E47F-DEA8-3232-34D8AD5149A5  2018-11-04      82.0  mg/dL     None
# 1   EFCDABEF-5B4F-CC75-AC10-110F1031F66B  2018-11-04      87.0  mg/dL     None
# 2   0B6F5417-EE1D-F8E1-EAA5-5DE7DA66F47D  2018-11-04     163.0  mg/dL     None
# 3   00900289-9F6F-274D-7B5F-29BE97284BF0  2018-11-04      83.0  mg/dL     None
# 4   3136FA35-6287-7C59-941A-4ECEC14B00BC  2018-11-04     159.0  mg/dL     None
# 5   D58CED07-2DEC-42AD-92E5-08C2691488FA  2018-11-04     159.0   None     None
# 6   49822F04-9471-FB96-A048-784C396D9719  2018-11-04     153.0  mg/dL     None
# 7   C50C5539-4D76-26CB-39FB-12990F8D3F0C  2018-11-04      69.0  mg/dL     None
# 8   39CC9D68-198F-1220-D7BE-06F366F3F1A3  2018-11-04      79.0   None     None
# 9   304B8F47-616F-7BFD-BA77-B269A0112AFB  2018-11-04      91.0  mg/dL     None
# 10  5E62BC1B-2D86-5936-171A-644102580F70  2018-11-04     125.0  mg/dL     None
# 11  03B3CCE4-1BCB-559C-6E50-A6CBCD7BC996  2018-11-04     203.0  mg/dL     None
# 12  6129090F-4C61-EB96-C42C-B5E6F6A5D80E  2018-11-04      63.0  mg/dL     None
# 13  2B3F45FC-8BE3-92B9-14EB-285F38580448  2018-11-04      46.0  mg/dL     None
# 14  29DC27F7-9C54-6A6B-7F40-312C939B27A4  2018-11-04     190.0  mg/dL     None
# 15  295BA735-131E-C3AF-87BD-7E460D784440  2018-11-04     108.0  MG/DL     None
# 16  686097EE-59C3-C93A-2405-B709619E087D  2018-11-04      63.0  mg/dL     None
# 17  124F8A2E-496B-B76E-5435-F0F03C2D37C8  2018-11-04     103.0  mg/dL     None
# 18  5F879091-84D9-6692-9247-0971296ECD86  2018-11-04      87.0  mg/dL     None
# 19  63F83A4C-D83F-E00B-6E04-0D1F1A8DC303  2018-11-04     239.0  mg/dL     None
# 20  3F90C01C-F477-D8A5-F4E1-E56717270958  2018-11-04     140.0  mg/dL     None
# 21  4649100B-4F9F-6AAD-27FB-2D38E4C85D98  2018-11-04     127.0  mg/dL     None
# 22  E5EE733F-B91A-019F-85F3-31D2A4E38B67  2018-11-04     367.0  mg/dL     None
# 23  9C8EDC6A-85FD-1E8C-C057-8EE8F68E27E5  2018-11-04     137.0  mg/dL     None
# 24  B2D163BB-3CDE-B9A4-3F1D-D430C5321506  2018-11-04     141.0  mg/dl     None
# 25  73DB417B-E21C-7BB6-EBDA-BC89328503F7  2018-11-04      60.0  mg/dL     None
# 26  1BA80E65-99B8-F4C6-1B10-72F2003CDD3D  2018-11-04      77.0  mg/dL     None
# 27  9A7C2942-E947-8E01-4952-34ACFF6261FE  2018-11-04     206.0  mg/dL     None
# 28  3CCF409B-0080-8D5D-0E6C-331843DDE2AA  2018-11-04      87.0  mg/dL     None
# 29  7725516B-8AE5-62EA-8408-4D87A4AD2770  2018-11-04      51.0  mg/dL     None
# 30  2E1B73E6-588A-714C-4CA6-241973F42F6B  2018-11-04     103.0  mg/dL     None
# 31  D7C404D1-8903-360E-E414-848338832125  2018-11-04      84.0  mg/dL     None
# 32  3CF636D8-569E-FF35-7A6C-088A72CF607C  2018-11-04     111.0  mg/dL     None
# 33  BE161C21-1F17-B267-2CD6-1CBC978B79A6  2018-11-04     143.0  mg/dL     None
# 34  A9165EBF-07A3-6079-39D0-311A5F797349  2018-11-04      81.0  mg/dL     None
# 35  B8406BB2-0DD6-B621-76F1-9A09126390F0  2018-11-04      84.0  mg/dL     None
# 36  8C6771EA-A296-B058-CD30-82FE57C5C835  2018-11-04      81.0  mg/dL     None
# 37  5A22ACF1-391F-F24B-8A41-0068F7FF1B05  2018-11-04      51.0  mg/dL     None
# 38  B8BDF942-204A-6C45-9293-44FA1F310B67  2018-11-04     155.0  mg/dL     None
# 39  DC6DD0E4-409F-D783-69C6-2652C2E9E9F0  2018-11-04     189.0  mg/dL     None
# 40  0FAB4D4B-0F1F-72F9-36A5-1D6F728C4AA4  2018-11-04     146.0  mg/dL     None
# 41  AE524C42-CD95-8B89-D28E-C0927BB20369  2018-11-04     211.0  mg/dL     None
# 42  57ADE6EA-DE0F-725F-1721-86FCF832158E  2018-11-04      83.0  mg/dL     None
# 43  90951023-A133-4623-CAA8-9C66C9F8AFBA  2018-11-04     238.0  mg/dL     None
# 44  E855C4D3-4DFB-4BB3-DF14-4838C70FB87A  2018-11-04      61.0  MG/DL     None
# 45  B037C6CB-A172-D616-7B42-2883D96F2431  2018-11-04     164.0  mg/dL     None
# 46  331B07D1-FA7B-6BD8-250A-3FF683D856E6  2018-11-04     134.0  mg/dL     None
# 47  60B9A9DE-EC74-8986-A378-D1CACFEBDCAC  2018-11-04     228.0  mg/dL     None
# 48  4AB3BCE8-E0D6-4AFD-1D20-8923E0DCDCB1  2018-11-04     271.0  mg/dL     None
# 49  A3F7E6C9-8430-6415-FBEB-A5E93D16C9B3  2018-11-04     154.0  mg/dL     None

# %%
# %%read_sql
#
# select  tg_level,
#         count(distinct patient_id)
#
#         from st_tg_cohort4
#
#         --where unit ilike '%mg/dL%'
#            --and hdl_unit ilike '%mg/dL%'
#
#         group by tg_level
#         --order by tg_level
# Out:
# Query started at 04:39:28 PM India Standard Time; Query executed in 0.05 m
#    tg_level  COUNT(DISTINCT PATIENT_ID)
# 0      None                     6413650
# 1  tg_gt500                      109900

# %% [markdown]
# ## HDL cohort
# - creating table for HDL levels

# %%
# %%read_sql
#
# create or replace table st_hdl_cohort as
#
# select
#     patient_id,
#     report_date as hdl_report_date,
#     obs_quan as hdl_value,
#     unit,
#
#     case
#         when obs_quan < 40 then 'hdl_lt40'
#         when obs_quan >= 40 then 'hdl_gt40'
#
#     end as hdl_level
#
# from st_tg_obs_cohort
#
# where loinc_num in (select value from st_loinc_ref where cat1 = 'loinc' and cat2 = 'tg'
#                             and cat3 = 'hdl' and deactive_date is null)
#         and result_status ilike '%Final%'
# Out:
# Query started at 04:40:15 PM India Standard Time; Query executed in 0.13 m
#                                       status
# 0  Table ST_HDL_COHORT successfully created.

# %%
snow.select("select * from st_hdl_cohort limit 50")
# Out:
#                               patient_id hdl_report_date  hdl_value   unit  \
# 0   96C7A2A2-4BCE-DCA0-CC95-E1ACBB40A1A9      2015-10-08       54.0  mg/dL
# 1   A7B38B8E-2D47-4712-3B1C-91DC9E13CC19      2017-12-13       60.0  mg/dL
# 2   A7B38B8E-2D47-4712-3B1C-91DC9E13CC19      2018-01-10       59.0  mg/dL
# 3   8779A09A-0C76-1010-D604-1A5B9F66BFA3      2017-04-22       43.0  mg/dL
# 4   4DB0B540-2043-F47C-DE5F-ADC208706BE8      2017-04-04       48.0  mg/dL
# 5   C2F17244-F79F-E892-0A2B-35204C9D70FA      2014-04-28      111.0  mg/dL
# 6   C2F17244-F79F-E892-0A2B-35204C9D70FA      2013-01-29      109.0  mg/dL
# 7   C2F17244-F79F-E892-0A2B-35204C9D70FA      2013-10-28      108.0  mg/dL
# 8   C2F17244-F79F-E892-0A2B-35204C9D70FA      2015-05-01      119.0  mg/dL
# 9   418D536D-DE81-6110-E482-4515325A840E      2018-03-13       43.0  mg/dL
# 10  418D536D-DE81-6110-E482-4515325A840E      2018-04-24       44.0  mg/dL
# 11  418D536D-DE81-6110-E482-4515325A840E      2017-04-29       45.0  mg/dL
# 12  549C8F97-FEBC-E1B4-C44F-919BCCA780F7      2014-03-25       43.0  mg/dL
# 13  84FFF2EF-2C58-C397-413F-65109362010C      2014-07-26       39.0  mg/dL
# 14  30B9D788-0B8E-9901-4AF4-324CDA1314AD      2016-12-24       67.0  mg/dL
# 15  4A4B4A45-D9ED-3AE1-6050-EEE209C83739      2015-11-29       56.0  mg/dL
# 16  4A4B4A45-D9ED-3AE1-6050-EEE209C83739      2013-04-04       49.0  mg/dL
# 17  4A4B4A45-D9ED-3AE1-6050-EEE209C83739      2013-09-20       59.0  mg/dL
# 18  4A4B4A45-D9ED-3AE1-6050-EEE209C83739      2014-10-14       51.0  mg/dL
# 19  6E037EBB-5194-E4C5-BC08-9FCD697FE415      2018-08-17       52.0  mg/dL
# 20  9261CFD0-D2EF-C50E-A8FC-A026AF3C591A      2014-03-02       43.0  mg/dL
# 21  994ED00F-911F-6685-D55D-B9840136DBF6      2015-11-03       57.0  mg/dL
# 22  68B39860-6F02-163E-F6F2-AAC418DA9579      2013-02-23       27.0  mg/dL
# 23  517C2583-2736-5710-DD6E-0012E7701085      2013-08-16       79.0  mg/dL
# 24  517C2583-2736-5710-DD6E-0012E7701085      2015-06-02       76.0  mg/dL
# 25  517C2583-2736-5710-DD6E-0012E7701085      2014-12-01       90.0  mg/dL
# 26  A5D7A947-FC83-8E79-85D0-4157F7CBCC3E      2017-10-23       79.0  MG/DL
# 27  C7263B24-EEB5-52DC-64CC-976EAE50B157      2014-06-12       60.0  mg/dL
# 28  944535EF-EA22-9762-4ECF-3D2C0238184E      2016-12-23       46.0  mg/dL
# 29  0960B23F-E1DB-1632-C87A-533112F08460      2015-09-01       66.0  mg/dL
# 30  0960B23F-E1DB-1632-C87A-533112F08460      2016-10-21       72.0  mg/dL
# 31  0960B23F-E1DB-1632-C87A-533112F08460      2017-03-09       85.0  mg/dL
# 32  0960B23F-E1DB-1632-C87A-533112F08460      2012-09-18       63.0  mg/dL
# 33  0960B23F-E1DB-1632-C87A-533112F08460      2014-12-16       62.0  mg/dL
# 34  EF58EB8D-CD9A-E4B5-A08E-CBFB378BF0DA      2017-04-21       68.0  mg/dL
# 35  EF58EB8D-CD9A-E4B5-A08E-CBFB378BF0DA      2017-02-17       53.0  mg/dL
# 36  37384CCD-51EE-0980-3FE7-4A9D4F1031DF      2016-07-12       31.0  mg/dL
# 37  2AD15E6A-69A6-BF1B-1871-8B0ECBC897E6      2017-04-30       39.0  mg/dL
# 38  B3487892-3AAC-389B-BDBE-71B168D96184      2017-12-11       42.0  mg/dL
# 39  B3487892-3AAC-389B-BDBE-71B168D96184      2016-12-02       47.0  mg/dL
# 40  B3487892-3AAC-389B-BDBE-71B168D96184      2018-05-19       44.0  mg/dL
# 41  821D6C56-D1EA-9CB4-41F3-AFE72C9418FE      2013-10-23       42.0  mg/dL
# 42  821D6C56-D1EA-9CB4-41F3-AFE72C9418FE      2013-03-06       44.0  mg/dL
# 43  821D6C56-D1EA-9CB4-41F3-AFE72C9418FE      2014-08-07       50.0  mg/dL
# 44  88406EF5-4474-65F6-3878-99296F91E6F0      2015-10-06       33.0  mg/dL
# 45  88406EF5-4474-65F6-3878-99296F91E6F0      2014-08-10       32.0  mg/dL
# 46  89B96399-7789-9EC3-D3B8-D668E9B45541      2017-06-09       55.0  mg/dL
# 47  89B96399-7789-9EC3-D3B8-D668E9B45541      2015-10-01       53.0  mg/dL
# 48  9547A83D-FD38-7929-CF7C-02A70DF5CE70      2016-08-09       46.0  mg/dL
# 49  3F04FDDB-60AB-1FC3-D43F-B21CE3FF79B6      2014-02-02       60.0  mg/dL
#
#    hdl_level
# 0   hdl_gt40
# 1   hdl_gt40
# 2   hdl_gt40
# 3   hdl_gt40
# 4   hdl_gt40
# 5   hdl_gt40
# 6   hdl_gt40
# 7   hdl_gt40
# 8   hdl_gt40
# 9   hdl_gt40
# 10  hdl_gt40
# 11  hdl_gt40
# 12  hdl_gt40
# 13  hdl_lt40
# 14  hdl_gt40
# 15  hdl_gt40
# 16  hdl_gt40
# 17  hdl_gt40
# 18  hdl_gt40
# 19  hdl_gt40
# 20  hdl_gt40
# 21  hdl_gt40
# 22  hdl_lt40
# 23  hdl_gt40
# 24  hdl_gt40
# 25  hdl_gt40
# 26  hdl_gt40
# 27  hdl_gt40
# 28  hdl_gt40
# 29  hdl_gt40
# 30  hdl_gt40
# 31  hdl_gt40
# 32  hdl_gt40
# 33  hdl_gt40
# 34  hdl_gt40
# 35  hdl_gt40
# 36  hdl_lt40
# 37  hdl_lt40
# 38  hdl_gt40
# 39  hdl_gt40
# 40  hdl_gt40
# 41  hdl_gt40
# 42  hdl_gt40
# 43  hdl_gt40
# 44  hdl_lt40
# 45  hdl_lt40
# 46  hdl_gt40
# 47  hdl_gt40
# 48  hdl_gt40
# 49  hdl_gt40

# %% [markdown]
# ## Final patient counts with tg levels and HDL
# - All the records have been matched on the report_date. I thought of it as a comorbidity where at a given time point (in our case report_date) we want to know the patient's tg level and hdl level.

# %% [markdown]
# ### Tg levels lt150 and gt150 and hdl counts

# %%
# %%read_sql
#
# create or replace table st_tg_hdl_agg1 as
# select a.patient_id,
#         a.obs_quan,
#      a.tg_level,
#      a.unit,
#      b.hdl_value,
#      b.unit as hdl_unit,
#      b.hdl_level
#  from
#     st_tg_cohort1 a
#         join st_hdl_cohort b
#             on a.patient_id = b.patient_id
#
#             where a.report_date = b.hdl_report_date
# --group by 1
# Out:
# Query started at 04:43:39 PM India Standard Time; Query executed in 0.17 m
#                                        status
# 0  Table ST_TG_HDL_AGG1 successfully created.

# %%
snow.select("select * from st_tg_hdl_agg1 limit 5")
# Out:
#                              patient_id  obs_quan  tg_level   unit  hdl_value  \
# 0  D543699F-63F9-56BA-37FD-C38A1BA527A7      63.0  tg_lt150  mg/dL       40.0
# 1  D543699F-63F9-56BA-37FD-C38A1BA527A7      91.0  tg_lt150  mg/dL       42.0
# 2  DFA6DDAA-242E-4096-3748-A3F1C637D115     118.0  tg_lt150  mg/dL       46.0
# 3  094393F2-4A2B-393A-4951-D1C7837D81C1      93.0  tg_lt150  mg/dL       73.0
# 4  F748A4BF-2872-64A0-9E80-02122C444629     242.0  tg_gt150  mg/dL       45.0
#
#   hdl_unit hdl_level
# 0    mg/dL  hdl_gt40
# 1    mg/dL  hdl_gt40
# 2    mg/dL  hdl_gt40
# 3    mg/dL  hdl_gt40
# 4    mg/dL  hdl_gt40

# %%
# %%read_sql
#
# select  tg_level,
#         hdl_level,
#         count(distinct patient_id)
#
#         from st_tg_hdl_agg1
#
#         --where unit ilike '%mg/dL%'
#            --and hdl_unit ilike '%mg/dL%'
#
#         group by tg_level, hdl_level
#         --order by tg_level
# Out:
# Query started at 04:48:39 PM India Standard Time; Query executed in 0.08 m
#    tg_level hdl_level  COUNT(DISTINCT PATIENT_ID)
# 0      None  hdl_lt40                         936
# 1  tg_gt150  hdl_gt40                     1626026
# 2  tg_lt150  hdl_lt40                      745365
# 3      None  hdl_gt40                        3258
# 4  tg_gt150  hdl_lt40                      977354
# 5  tg_gt150      None                        2066
# 6  tg_lt150  hdl_gt40                     4500249
# 7  tg_lt150      None                        3055
# 8      None      None                       43351

# %% [markdown]
# ### Tg levels gt180 and hdl counts

# %%
# %%read_sql
#
# create or replace table st_tg_hdl_agg2 as
# select a.patient_id,
#         a.obs_quan,
#      a.tg_level,
#      a.unit,
#      b.hdl_value,
#      b.unit as hdl_unit,
#      b.hdl_level
#  from
#     st_tg_cohort2 a
#         join st_hdl_cohort b
#             on a.patient_id = b.patient_id
#
#             where a.report_date = b.hdl_report_date
# --group by 1
# Out:
# Query started at 04:50:56 PM India Standard Time; Query executed in 0.23 m
#                                        status
# 0  Table ST_TG_HDL_AGG2 successfully created.

# %%
# %%read_sql
#
# select  tg_level,
#         hdl_level,
#         count(distinct patient_id)
#
#         from st_tg_hdl_agg2
#
#         --where unit ilike '%mg/dL%'
#            --and hdl_unit ilike '%mg/dL%'
#
#         group by tg_level, hdl_level
#         --order by tg_level
# Out:
# Query started at 05:08:30 PM India Standard Time; Query executed in 0.12 m
#    tg_level hdl_level  COUNT(DISTINCT PATIENT_ID)
# 0      None  hdl_lt40                      953115
# 1      None  hdl_gt40                     4896650
# 2  tg_gt180      None                        1743
# 3  tg_gt180  hdl_gt40                     1048525
# 4  tg_gt180  hdl_lt40                      784308
# 5      None      None                       45307

# %% [markdown]
# ### Tg levels gt200 and hdl counts

# %%
# %%read_sql
#
# create or replace table st_tg_hdl_agg3 as
# select a.patient_id,
#         a.obs_quan,
#      a.tg_level,
#      a.unit,
#      b.hdl_value,
#      b.unit as hdl_unit,
#      b.hdl_level
#  from
#     st_tg_cohort3 a
#         join st_hdl_cohort b
#             on a.patient_id = b.patient_id
#
#             where a.report_date = b.hdl_report_date
# --group by 1
# Out:
# Query started at 05:11:11 PM India Standard Time; Query executed in 0.31 m
#                                        status
# 0  Table ST_TG_HDL_AGG3 successfully created.

# %%
# %%read_sql
#
# select  tg_level,
#         hdl_level,
#         count(distinct patient_id)
#
#         from st_tg_hdl_agg3
#
#         --where unit ilike '%mg/dL%'
#            --and hdl_unit ilike '%mg/dL%'
#
#         group by tg_level, hdl_level
#         --order by tg_level
# Out:
# Query started at 05:12:10 PM India Standard Time; Query executed in 0.10 m
#    tg_level hdl_level  COUNT(DISTINCT PATIENT_ID)
# 0      None  hdl_lt40                     1061297
# 1  tg_gt200  hdl_lt40                      671657
# 2      None  hdl_gt40                     5056237
# 3  tg_gt200  hdl_gt40                      781917
# 4  tg_gt200      None                        1576
# 5      None      None                       45381

# %% [markdown]
# ### Tg levels gt500 and hdl counts

# %%
# %%read_sql
#
# create or replace table st_tg_hdl_agg4 as
# select a.patient_id,
#         a.obs_quan,
#      a.tg_level,
#      a.unit,
#      b.hdl_value,
#      b.unit as hdl_unit,
#      b.hdl_level
#  from
#     st_tg_cohort4 a
#         join st_hdl_cohort b
#             on a.patient_id = b.patient_id
#
#             where a.report_date = b.hdl_report_date
# --group by 1
# Out:
# Query started at 05:13:25 PM India Standard Time; Query executed in 0.23 m
#                                        status
# 0  Table ST_TG_HDL_AGG4 successfully created.

# %%
# %%read_sql
#
# select  tg_level,
#         hdl_level,
#         count(distinct patient_id)
#
#         from st_tg_hdl_agg4
#
#         --where unit ilike '%mg/dL%'
#            --and hdl_unit ilike '%mg/dL%'
#
#         group by tg_level, hdl_level
#         --order by tg_level
# Out:
# Query started at 05:13:43 PM India Standard Time; Query executed in 0.10 m
#    tg_level hdl_level  COUNT(DISTINCT PATIENT_ID)
# 0      None  hdl_lt40                     1488844
# 1  tg_gt500      None                        1002
# 2  tg_gt500  hdl_gt40                       25086
# 3      None  hdl_gt40                     5419485
# 4  tg_gt500  hdl_lt40                       87867
# 5      None      None                       45682

# %% [markdown]
# # Notes for Nish
# - My main concern is that a patient diagnosed in say, 2015 with x level of tg and y level of hdl may not have the same values in 2017. Using a distinct function will pick the first record for that patient_id so it doesn't really resolve my problem.
# - Right now, I am treating these buckets as exclusive of each other but I am not sure if it is the right approach. I tried using the max(report_date) function to get the latest EHR record but the results were very weird so I went back to a more simplistic kinda approach.
